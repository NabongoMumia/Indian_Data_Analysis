# %% [markdown]
# ## INDIAN STARTUP FUNDING ANALYSIS PROJECT
#
#
# Project Title - The Indian Start-Up Funding Project
#
# * Context
#
# The data for this project spans from 2018-2019. Our goal will be to satisfy the processes for handling the data and also provide a detailed analysis of the process using the CRISP-DM data analysis framework.
#
# This Notebook will include conclusions on the following :
#
# * Asking the relevant questions and stating some hypothesis.
# * Cleaning the data.
#
# Questions?
#
# * Do companies in certain sectors tend to receive more funding than others?
#
# * Is there a correlation between the stage of development of a company and the amount of funding it receives?
#
# * Are companies with more founders more likely to receive larger amounts of funding?
#
# * Are there any patterns in the location of a company's headquarters and the amount of funding it receives?
#
# * Does the number of investors in a company tend to impact the amount of funding it receives?
#
# * Founders: How many founders are associated with each company? What is the average number of founders?
#
# * What are the top 10 companies with the highest funding?
#
#
# Hypothesis!
#
# * Startups in the e-commerce and fintech sectors receive more funding compared to the technology sector in India.
#
# * There is a positive correlation between the stage of development of a company and the amount of funding it receives in India.
#
# * Companies with a larger number of founders are more likely to receive higher amounts of funding in India.
#
# * Startups headquartered in major metropolitan areas such as Mumbai, Bangalore, and Delhi are more likely to receive larger amounts of funding in India.
#
# * The number of investors in a company is positively correlated with the amount of funding it receives in India.
#
# * Is there a relationship between the sector of a company and the amount of funding it receives?
#
# * Is there a difference in the average funding received by companies headquartered in different regions?
#
#
# ## Cleaning the data.
# * Replacing missing values by using mode of the column
#
# * Dropping values and duplicates
#
# * Renaming values using loc method
#
# * Replacing missing values with averages: This was done by accessing the distribution of the data
#
# * Handling missing values by using loc method.
#
# * Creating a date series to spread the data out in a time frame.
#
# * Convert currency from rupees to dollars by writing a function.
#
# * Filling the missing values in the amount column by: converting the structure of the data and filling  * it the distribution of the data with the aid of a histogram and box plot, Then using the median as standard.
#
# * Restructuring the sector column by first creating a several lists of Keywords realted to different sector industries. Then using the pandas 'str.contain()' method to check if any keyword in each appear in the sector column for each row of the dataframe.If so,it will assign it to the corresponding industry label in the new column created for that row.

# %% [markdown]
# ## Importing libraries & accessing the size and shape of the data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
ind_2018 = pd.read_csv('C:\\Users\\DELL\\OneDrive\\Desktop\\Indian_Data_Analysis\\assets\\startup_funding2018.csv')
ind_2019 = pd.read_csv('C:\\Users\\DELL\\oneDrive\\Desktop\\Indian_Data_Analysis\\assets\\startup_funding2019.csv')
ind_2020 = pd.read_csv('C:\\Users\\DELL\\oneDrive\\Desktop\\Indian_Data_Analysis\\assets\\startup_funding2020.csv')
ind_2021 = pd.read_csv('C:\\Users\\DELL\\oneDrive\\Desktop\\Indian_Data_Analysis\\assets\\startup_funding2021.csv')

# %%
ind_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
ind_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
ind_2018.isna().sum()
# Out:
# Company Name     0
# Industry         0
# Round/Series     0
# Amount           0
# Location         0
# About Company    0
# dtype: int64

# %% [markdown]
# ## Filtering the data ,replacing and rename values & a date series(random)

# %%
ind_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
ind_2018['Year']=2018
ind_2018['Founded']='NaN'
ind_2018= ind_2018.rename(columns={'Company Name': 'Company/Brand'})
ind_2018= ind_2018.rename(columns={'Industry': 'Sector'})
ind_2018= ind_2018.rename(columns={'Location': 'HeadQuarter'})
ind_2018= ind_2018.rename(columns={'Amount': 'Amount($)'})
ind_2018= ind_2018.rename(columns={'Round/Series': 'Stage'})
ind_2018.drop('About Company',axis=1,inplace=True)

# %%
# replace empty values with NaN
ind_2018['Sector'].replace('—', pd.np.nan, inplace=True)

# %%
ind_2018.loc[58, 'Sector'] = 'Entertainment'
ind_2018.loc[105, 'Sector'] = 'Finance'
ind_2018.loc[121, 'Sector'] = 'Automotive'
ind_2018.loc[146, 'Sector'] = 'Automotive'
ind_2018.loc[153, 'Sector'] = 'Food'
ind_2018.loc[174, 'Sector'] = 'Technology'
ind_2018.loc[181, 'Sector'] = 'Finance'
ind_2018.loc[210, 'Sector'] = 'Automotive'
ind_2018.loc[230, 'Sector'] = 'Real Estate'
ind_2018.loc[235, 'Sector'] = 'Technology'
ind_2018.loc[238, 'Sector'] = 'Technology'
ind_2018.loc[242, 'Sector'] = 'Real Estate'
ind_2018.loc[243, 'Sector'] = 'Technology'
ind_2018.loc[247, 'Sector'] = 'Technology'
ind_2018.loc[251, 'Sector'] = 'Wellness'
ind_2018.loc[257, 'Sector'] = 'Marketing'
ind_2018.loc[258, 'Sector'] = 'Marketing'
ind_2018.loc[259, 'Sector'] = 'E-Commerce'
ind_2018.loc[257, 'Sector'] = 'Marketing'
ind_2018.loc[294, 'Sector'] = 'Transportation'
ind_2018.loc[325, 'Sector'] = 'Technology'
ind_2018.loc[326, 'Sector'] = 'Finance'
ind_2018.loc[346, 'Sector'] = 'Finance'
ind_2018.loc[398, 'Sector'] = 'Finance'
ind_2018.loc[457, 'Sector'] = 'Agriculture'
ind_2018.loc[472, 'Sector'] = 'Technology'
ind_2018.loc[473, 'Sector'] = 'Technology'
ind_2018.loc[476, 'Sector'] = 'Technology'
ind_2018.loc[478, 'Sector'] = 'Wellness/Beauty'
ind_2018.loc[480, 'Sector'] = 'Hospitality'
ind_2018.loc[510, 'Sector'] = 'Technology'

# %%
ind_2018.head(511)
# Out:
#        Company/Brand                                             Sector  \
# 0    TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1    Happy Cow Dairy                               Agriculture, Farming
# 2         MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3        PayMe India                        Financial Services, FinTech
# 4           Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..               ...                                                ...
# 506           Verzeo                                         E-Learning
# 507           Haazri                 Food and Beverage, Snack Food, Tea
# 508    Connect India            Delivery Service, E-Commerce, Logistics
# 509          Flyrobe                         Fashion, Lifestyle, Rental
# 510         Scholify                                                  —
#
#         Stage     Amount($)                       HeadQuarter  Year Founded
# 0        Seed        250000       Bangalore, Karnataka, India  2018     NaN
# 1        Seed   ₹40,000,000        Mumbai, Maharashtra, India  2018     NaN
# 2    Series A   ₹65,000,000           Gurgaon, Haryana, India  2018     NaN
# 3       Angel       2000000       Noida, Uttar Pradesh, India  2018     NaN
# 4        Seed             —  Hyderabad, Andhra Pradesh, India  2018     NaN
# ..        ...           ...                               ...   ...     ...
# 506  Series A       5000000       Bangalore, Karnataka, India  2018     NaN
# 507      Seed   ₹12,500,000        Mumbai, Maharashtra, India  2018     NaN
# 508     Angel             —           New Delhi, Delhi, India  2018     NaN
# 509  Series B  ₹264,000,000        Mumbai, Maharashtra, India  2018     NaN
# 510  Pre-Seed             —       Bengaluru, Karnataka, India  2018     NaN
#
# [511 rows x 7 columns]

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand    0
# Sector           0
# Stage            0
# Amount($)        0
# HeadQuarter      0
# Year             0
# Founded          0
# dtype: int64

# %% [markdown]
# ## Filling the anomalies in this column by containing the valid values and replacing the missing values

# %%
# # create a DatetimeIndex with dates for the entire year
date_range = pd.date_range(start='2018-01-01', end='2018-12-31', freq='D')

# # create a new column 'Date' with random dates within the year 2018
ind_2018['Date'] = np.random.choice(date_range, size=len(ind_2018))

ind_2018 = ind_2018.sort_values('Date')

ind_2018['Date'] = pd.to_datetime(ind_2018['Date'], format='%Y-%m-%d')

# %%
ind_2018.set_index('Date',inplace=True)

# %% [markdown]
# ## Changing the shape of the amount col & currency(rates conidered),filling the missing values with mean of the column.

# %%
def convert_to_dollars(value):
    if pd.isnull(value):
        return np.nan
    elif isinstance(value, float):
        return str(value)
    elif '$' in value:
        return value
    elif '₹' in value:
        return '$' + str(round(float(value.split('₹')[1].replace(',', '')) / 68.44, 2))
    else:
        return '$' + str(float(value) / 68.44)


# convert values in 'Amount($)' column to strings
ind_2018['Amount($)'] = ind_2018['Amount($)'].astype(str)

ind_2018['Amount($)'] = ind_2018['Amount($)'].str.replace('[^\d\.]', '')

ind_2018['Amount($)'].replace('', np.nan, inplace=True)

ind_2018['Amount($)'] = ind_2018['Amount($)'].astype(float)

ind_2018['Amount($)'] = ind_2018['Amount($)'].apply(convert_to_dollars)

# %%
# # convert the 'Amount' column to a numeric data type
ind_2018['Amount($)'] = pd.to_numeric(ind_2018['Amount($)'])
ind_2018['Amount($)'] = pd.to_numeric(ind_2018['Amount($)'])

# %%
ind_2018.describe()
# Out:
#           Amount($)    Year
# count  3.780000e+02   526.0
# mean   2.391683e+08  2018.0
# std    1.374900e+09     0.0
# min    7.500000e+03  2018.0
# 25%    1.000000e+06  2018.0
# 50%    5.800000e+06  2018.0
# 75%    5.000000e+07  2018.0
# max    2.000000e+10  2018.0

# %%
ind_2018.duplicated()
# Out:
# Date
# 2018-01-01    False
# 2018-01-01    False
# 2018-01-02    False
# 2018-01-03    False
# 2018-01-03    False
#               ...
# 2018-12-30    False
# 2018-12-31    False
# 2018-12-31    False
# 2018-12-31    False
# 2018-12-31    False
# Length: 526, dtype: bool

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand      0
# Sector             0
# Stage              0
# Amount($)        148
# HeadQuarter        0
# Year               0
# Founded            0
# dtype: int64

# %%
ind_2018.head()
# Out:
#                 Company/Brand  \
# Date
# 2018-01-01            Vebbler
# 2018-01-01          StockEdge
# 2018-01-02     Max Healthcare
# 2018-01-03  Creator’s Gurukul
# 2018-01-03   Innov8 Coworking
#
#                                                        Sector  \
# Date
# 2018-01-01        File Sharing, Personalization, Social Media
# 2018-01-01                   Analytics, Apps, Market Research
# 2018-01-02     Health Care, Hospital, Supply Chain Management
# 2018-01-03                        Facilities Support Services
# 2018-01-03  Collaboration, Communities, Coworking, Real Es...
#
#                       Stage  Amount($)                  HeadQuarter  Year  \
# Date
# 2018-01-01             Seed        NaN  Bengaluru, Karnataka, India  2018
# 2018-01-01             Seed  1100000.0  Kolkata, West Bengal, India  2018
# 2018-01-02  Corporate Round        NaN      New Delhi, Delhi, India  2018
# 2018-01-03            Angel        NaN      Gurgaon, Haryana, India  2018
# 2018-01-03             Seed  4000000.0      New Delhi, Delhi, India  2018
#
#            Founded
# Date
# 2018-01-01     NaN
# 2018-01-01     NaN
# 2018-01-02     NaN
# 2018-01-03     NaN
# 2018-01-03     NaN

# %%
# Create a histogram of the 'Amount' column
plt.hist(ind_2018['Amount($)'], bins=20)
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.ylabel('Frequency')
plt.show()

# %%
ind_2018['Amount($)'] = ind_2018['Amount($)'].fillna(ind_2018['Amount($)'].median())

# %%
ind_2018['Amount($)'] = ind_2018['Amount($)'].astype(int)

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand    0
# Sector           0
# Stage            0
# Amount($)        0
# HeadQuarter      0
# Year             0
# Founded          0
# dtype: int64

# %%
ind_2018.head(100)
# Out:
#                 Company/Brand  \
# Date
# 2018-01-01            Vebbler
# 2018-01-01          StockEdge
# 2018-01-02     Max Healthcare
# 2018-01-03  Creator’s Gurukul
# 2018-01-03   Innov8 Coworking
# ...                       ...
# 2018-03-11          Mate Labs
# 2018-03-12                OYO
# 2018-03-13       Strom Motors
# 2018-03-16    Buddy4Study.com
# 2018-03-17            Emojifi
#
#                                                        Sector  \
# Date
# 2018-01-01        File Sharing, Personalization, Social Media
# 2018-01-01                   Analytics, Apps, Market Research
# 2018-01-02     Health Care, Hospital, Supply Chain Management
# 2018-01-03                        Facilities Support Services
# 2018-01-03  Collaboration, Communities, Coworking, Real Es...
# ...                                                       ...
# 2018-03-11    Artificial Intelligence, Machine Learning, PaaS
# 2018-03-12                Hospitality, Hotel, Leisure, Travel
# 2018-03-13                                         Automotive
# 2018-03-16  Career Planning, Education, Higher Education, ...
# 2018-03-17                                           Internet
#
#                       Stage  Amount($)                  HeadQuarter  Year  \
# Date
# 2018-01-01             Seed    5800000  Bengaluru, Karnataka, India  2018
# 2018-01-01             Seed    1100000  Kolkata, West Bengal, India  2018
# 2018-01-02  Corporate Round    5800000      New Delhi, Delhi, India  2018
# 2018-01-03            Angel    5800000      Gurgaon, Haryana, India  2018
# 2018-01-03             Seed    4000000      New Delhi, Delhi, India  2018
# ...                     ...        ...                          ...   ...
# 2018-03-11             Seed     550000  Bangalore, Karnataka, India  2018
# 2018-03-12         Series E  100000000      Gurgaon, Haryana, India  2018
# 2018-03-13            Angel    5800000   Mumbai, Maharashtra, India  2018
# 2018-03-16         Series A    3000000  Noida, Uttar Pradesh, India  2018
# 2018-03-17             Seed    5800000  Bengaluru, Karnataka, India  2018
#
#            Founded
# Date
# 2018-01-01     NaN
# 2018-01-01     NaN
# 2018-01-02     NaN
# 2018-01-03     NaN
# 2018-01-03     NaN
# ...            ...
# 2018-03-11     NaN
# 2018-03-12     NaN
# 2018-03-13     NaN
# 2018-03-16     NaN
# 2018-03-17     NaN
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Replacing missing values in stage & Founded col / filtering headquater col / filtering the sector col by closing them in related col by using str.contain

# %%
valid_stages = ['Venture - Series Unknown','Seed', 'Angel', 'Series A', 'Series B', 'Pre-Seed', 'Grant', 'Series H', 
                'Series A', 'Series C', 'Series E', 'Corporate Round','Series D','Debt financing','Post-IPO Equity']

ind_2018.loc[~ind_2018['Stage'].isin(valid_stages), 'Stage'] = np.nan

# %%
mode_value = ind_2018['Stage'].mode()[0]
print(mode_value)
# Out:
# Seed

# %%
ind_2018['Stage'] = ind_2018['Stage'].fillna(ind_2018['Stage'].mode()[0])
ind_2018['Founded'] = ind_2018['Founded'].replace('NaN', np.nan)

# %%
ind_2018.head(100)
# Out:
#                 Company/Brand  \
# Date
# 2018-01-01            Vebbler
# 2018-01-01          StockEdge
# 2018-01-02     Max Healthcare
# 2018-01-03  Creator’s Gurukul
# 2018-01-03   Innov8 Coworking
# ...                       ...
# 2018-03-11          Mate Labs
# 2018-03-12                OYO
# 2018-03-13       Strom Motors
# 2018-03-16    Buddy4Study.com
# 2018-03-17            Emojifi
#
#                                                        Sector  \
# Date
# 2018-01-01        File Sharing, Personalization, Social Media
# 2018-01-01                   Analytics, Apps, Market Research
# 2018-01-02     Health Care, Hospital, Supply Chain Management
# 2018-01-03                        Facilities Support Services
# 2018-01-03  Collaboration, Communities, Coworking, Real Es...
# ...                                                       ...
# 2018-03-11    Artificial Intelligence, Machine Learning, PaaS
# 2018-03-12                Hospitality, Hotel, Leisure, Travel
# 2018-03-13                                         Automotive
# 2018-03-16  Career Planning, Education, Higher Education, ...
# 2018-03-17                                           Internet
#
#                       Stage  Amount($)                  HeadQuarter  Year  \
# Date
# 2018-01-01             Seed    5800000  Bengaluru, Karnataka, India  2018
# 2018-01-01             Seed    1100000  Kolkata, West Bengal, India  2018
# 2018-01-02  Corporate Round    5800000      New Delhi, Delhi, India  2018
# 2018-01-03            Angel    5800000      Gurgaon, Haryana, India  2018
# 2018-01-03             Seed    4000000      New Delhi, Delhi, India  2018
# ...                     ...        ...                          ...   ...
# 2018-03-11             Seed     550000  Bangalore, Karnataka, India  2018
# 2018-03-12         Series E  100000000      Gurgaon, Haryana, India  2018
# 2018-03-13            Angel    5800000   Mumbai, Maharashtra, India  2018
# 2018-03-16         Series A    3000000  Noida, Uttar Pradesh, India  2018
# 2018-03-17             Seed    5800000  Bengaluru, Karnataka, India  2018
#
#             Founded
# Date
# 2018-01-01      NaN
# 2018-01-01      NaN
# 2018-01-02      NaN
# 2018-01-03      NaN
# 2018-01-03      NaN
# ...             ...
# 2018-03-11      NaN
# 2018-03-12      NaN
# 2018-03-13      NaN
# 2018-03-16      NaN
# 2018-03-17      NaN
#
# [100 rows x 7 columns]

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand      0
# Sector             0
# Stage              0
# Amount($)          0
# HeadQuarter        0
# Year               0
# Founded          526
# dtype: int64

# %%
# Split the Headquarters column by comma, and keep only the first value
ind_2018["City"] = ind_2018["HeadQuarter"].apply(lambda x: x.split(",")[0])

# %%
ind_2018.head()
# Out:
#                 Company/Brand  \
# Date
# 2018-01-01            Vebbler
# 2018-01-01          StockEdge
# 2018-01-02     Max Healthcare
# 2018-01-03  Creator’s Gurukul
# 2018-01-03   Innov8 Coworking
#
#                                                        Sector  \
# Date
# 2018-01-01        File Sharing, Personalization, Social Media
# 2018-01-01                   Analytics, Apps, Market Research
# 2018-01-02     Health Care, Hospital, Supply Chain Management
# 2018-01-03                        Facilities Support Services
# 2018-01-03  Collaboration, Communities, Coworking, Real Es...
#
#                       Stage  Amount($)                  HeadQuarter  Year  \
# Date
# 2018-01-01             Seed    5800000  Bengaluru, Karnataka, India  2018
# 2018-01-01             Seed    1100000  Kolkata, West Bengal, India  2018
# 2018-01-02  Corporate Round    5800000      New Delhi, Delhi, India  2018
# 2018-01-03            Angel    5800000      Gurgaon, Haryana, India  2018
# 2018-01-03             Seed    4000000      New Delhi, Delhi, India  2018
#
#             Founded       City
# Date
# 2018-01-01      NaN  Bengaluru
# 2018-01-01      NaN    Kolkata
# 2018-01-02      NaN  New Delhi
# 2018-01-03      NaN    Gurgaon
# 2018-01-03      NaN  New Delhi

# %%
ind_2018.drop('HeadQuarter',axis=1,inplace=True)

# %%
ind_2018 = ind_2018.rename(columns={'City': 'HeadQuarter'})

# %%
# replace "Bengaluru" with "Bangalore" in the "headquarter" column
ind_2018['HeadQuarter'] = ind_2018['HeadQuarter'].str.replace('Bengaluru', 'Bangalore')
ind_2018['HeadQuarter'] = ind_2018['HeadQuarter'].str.replace('Bangalore City', 'Bangalore')
ind_2018['HeadQuarter'] = ind_2018['HeadQuarter'].str.replace('New Delhi', 'Delhi')
ind_2018['HeadQuarter'] = ind_2018['HeadQuarter'].str.replace('Gurgaon', 'Gurugram')

# %%
unique_values = ind_2018['HeadQuarter'].unique()
print(unique_values)
# Out:
# ['Bangalore' 'Kolkata' 'Delhi' 'Gurugram' 'Ahmedabad' 'Mumbai' 'Hyderabad'
#  'Noida' 'Jaipur' 'Kochi' 'Pune' 'Haryana' 'Chennai' 'Anand' 'India'
#  'Bhopal' 'Ghaziabad' 'Indore' 'Thane' 'Lucknow' 'Ernakulam' 'Chandigarh'
#  'Azadpur' 'Andheri' 'Mohali' 'Worli' 'Guindy' 'Uttar Pradesh' 'Alwar'
#  'Jodhpur' 'Belgaum' 'Kalpakkam' 'Coimbatore' 'Trivandrum' 'Kormangala'
#  'Powai' 'Hubli' 'Alleppey' 'Faridabad' 'Kanpur' 'Kannur' 'Margão'
#  'Cochin' 'Guntur' 'Mylapore' 'Kalkaji' 'Kota']

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand      0
# Sector             0
# Stage              0
# Amount($)          0
# Year               0
# Founded          526
# HeadQuarter        0
# dtype: int64

# %%
tech = ['Mobile','Technology', 'Internet', 'Software', 'Hardware','SaaS','Blockchain','Apps','Information Services','SEM',
        'Artificial Intelligence','CleanTech','Aerospace','Robotics','Ai','PaaS','Medtech','Agritech','HR tech',
       'Tech','FoodTech','Safety tech','IoT','Legal tech','Infratech','Netwokring platform','Telecommunication','Cloud','Aero',
       'Virtual','Content','Photonics','app','Proptech','Deeptech','AR','VR','Agri tech','-Tech','AgriTech','IT','Network',
        'Data','HrTech','Foodtech','Spacetech','E-mobility','Automation','Logitech','HRTech','Drone','MLOps','Innovation',
       'BioTechnology','TaaS','network','equipment','SpaceTech','CRM','MarTech','Nanotechnology','Femtech','startup','AI']
fin = ['Lending','Finance','Insurance', 'Payments','Financial Services','Credit','Credit Cards','Mutual Funds',
       'Banking','Escrow','Venture','financial','Taxation','Capital','firm','Equity']
fint = ['NFT','Virtual Banking','FinTech','Fintech','Cryptocurrency','Crypto','Insurtech','InsurTech']
health = ['Health', 'Medical','Pharmaceutical','Health Diagnotics','Health Care','Hospital','Biotechnology','Biopharma',
         'Hygiene management','HealthTech','Healthcare','HealthCare','laboratory','Biotech','Healthtech','HeathTech',
         'Helathcare','Veterinary']
mkt = ['Brand Marketing','Marketing','Event Promotion','Market']
agric = ['Farming','Agriculture','Nutrition','Hauz Khas','Fishery']
con = ['Food','Food and Beverages','Dairy','Beverages','Beer','FMCG']
econ = ['B2B','Shopping','E-Commerce','Trading Platform','E-commerce','E-marketplace','marketplace','e-commerce','Ecommerce',
        'E-market','Commerce','Trading platform']
cons = ['Wholesale','Consumer','Shoes','Packaging','Retail','Consulting','Food Delivery']
edu = ['E-Learning','EdTech','Education','Communities','Edtech','Preschool','School']
welln = ['Lifestyle','Beauty','Wellness','Cosmetics','Yoga','Skincare','D2C','Fitness','Lifestyle','Training']
real_est=['Real Estate','Home Decor','Accomodation','Interior design','Home Design','Home interior','Co-living',
          'Construction']
log = ['Logistics','Rental','Tourism','Travel','TravelTech','Transport','Transportation','Aviation','Mobility']

auto = ['Automotive','Electric vehicle','Industrial Automation','Vehicles','Automotive tech','Automobile','Tyre','car','Car',
       'Vehicle','Mechanical']
manu = ['Manufacturing']
ener = ['Renewable Energy','Solar','Energy','Energy Storage','Battery','Oil and Gas','Renewable','EV','Electricity',
       'purification','Renewables']
medi = ['Entertainment','Media','News','Video','Digital Media','FM','Publication','OTT','Social Network','Music',
        'Digital platform','Podcast','publishing','Blogging']
game = ['Gaming','Games','Sports']

style = ['Fashion','Jewelry','Eyeglasses','Eye Wear','Apparel','Dating','Celebrity','Eyewear','D2C Fashion','Matrimony',
         'Textiles','D2C jewellery','Foootwear','Arts']
hos =['Hospitality','Hotel','Leisure']



ind_2018['Sector_clean'] = 'Other'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(tech)), 'Sector_clean'] = 'Technology'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(fin)), 'Sector_clean'] = 'Finance'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(health)), 'Sector_clean'] = 'Healthcare'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(mkt)), 'Sector_clean'] = 'Marketing'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(agric)), 'Sector_clean'] = 'Agriculture'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(econ)), 'Sector_clean'] = 'E-Commerce'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(edu)), 'Sector_clean'] = 'Education'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(welln)), 'Sector_clean'] = 'Wellness/Beauty'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(real_est)), 'Sector_clean'] = 'Real Estate'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(log)), 'Sector_clean'] = 'Logistics'

ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(auto)), 'Sector_clean'] = 'Automotive'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(manu)), 'Sector_clean'] = 'Manufacture'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(ener)), 'Sector_clean'] = 'Energy'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(medi)), 'Sector_clean'] = 'Media/Entertainment'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(hos)), 'Sector_clean'] = 'Hospitality'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(style)), 'Sector_clean'] = 'Lifestyle'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(cons)), 'Sector_clean'] = 'Consumer Services'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(game)), 'Sector_clean'] = 'Gaming'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(fint)), 'Sector_clean'] = 'FinTech'
ind_2018.loc[ind_2018['Sector'].str.contains('|'.join(con)), 'Sector_clean'] = 'Consumables'

# %%
ind_2018.drop('Sector',axis=1,inplace=True)

# %%
ind_2018= ind_2018.rename(columns={'Sector_clean': 'Sector'})

# %%
ind_2018.head()
# Out:
#                 Company/Brand            Stage  Amount($)  Year  Founded  \
# Date
# 2018-01-01            Vebbler             Seed    5800000  2018      NaN
# 2018-01-01          StockEdge             Seed    1100000  2018      NaN
# 2018-01-02     Max Healthcare  Corporate Round    5800000  2018      NaN
# 2018-01-03  Creator’s Gurukul            Angel    5800000  2018      NaN
# 2018-01-03   Innov8 Coworking             Seed    4000000  2018      NaN
#
#            HeadQuarter               Sector
# Date
# 2018-01-01   Bangalore  Media/Entertainment
# 2018-01-01     Kolkata            Marketing
# 2018-01-02       Delhi           Automotive
# 2018-01-03    Gurugram                Other
# 2018-01-03       Delhi          Real Estate

# %% [markdown]
# ## Ploting visuals to check the shape of the dataframe

# %%
import seaborn as sns

# Plot a line chart of funding amounts over time
funding_over_time = ind_2018.groupby('Date')['Amount($)'].sum().reset_index()
sns.lineplot(data=funding_over_time, x='Date', y='Amount($)')
plt.show()

# %%
if ind_2018.empty:
    print("No data found for the year 2018")
else:
    # Calculate the total funding by sector
    total_funding_by_sector = ind_2018.groupby('Sector')['Amount($)'].sum().reset_index()

    top_10_sectors = total_funding_by_sector.sort_values(by='Amount($)', ascending=False).head(10)

    ax = sns.barplot(data=top_10_sectors, x='Sector', y='Amount($)')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    plt.show()

# %% [markdown]
# ## 2019

# %% [markdown]
# ## Accessing the shape of the data, Filling the missing the val with statistical means,Dropping columns,Creating a date series

# %%
ind_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
ind_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
ind_2019.describe()
# Out:
#            Founded
# count    60.000000
# mean   2014.533333
# std       2.937003
# min    2004.000000
# 25%    2013.000000
# 50%    2015.000000
# 75%    2016.250000
# max    2019.000000

# %%
ind_2019.isna().sum()
# Out:
# Company/Brand     0
# Founded          29
# HeadQuarter      19
# Sector            5
# What it does      0
# Founders          3
# Investor          0
# Amount($)         0
# Stage            46
# dtype: int64

# %%
ind_2019.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# Length: 89, dtype: bool

# %%
ind_2019['Year'] = 2019

# %%
import pandas as pd
import numpy as np

ind_2019 = pd.DataFrame({
    'Sector': ['Tech', 'Finance', '—', 'Retail', 'Healthcare'],
    'Revenue': [10000, 5000, np.nan, 8000, 7000],
    'Year': [np.nan, 2019, np.nan, 2019, 2019]
})

ind_2019['Sector'].replace('—', np.nan, inplace=True)
ind_2019['Year'] = 2019

# %%
ind_2019.isna().sum()
# Out:
# Company/Brand     0
# Founded          29
# HeadQuarter      19
# Sector            5
# What it does      0
# Founders          3
# Investor          0
# Amount($)         0
# Stage            46
# Year              0
# dtype: int64

# %%
ind_2019.loc[41, 'Sector'] = 'Media'
ind_2019.loc[49, 'Sector'] = 'Human Resources'
ind_2019.loc[52, 'Sector'] = 'Technology'
ind_2019.loc[56, 'Sector'] = 'Technology'
ind_2019.loc[57, 'Sector'] = 'E-Commerce'

# %%
ind_2019.drop('What it does',axis=1,inplace=True)

# %%
# # create a DatetimeIndex with dates for the entire year
date_range = pd.date_range(start='2019-01-01', end='2019-12-31', freq='D')

# # create a new column 'Date' with random dates within the year 2018
ind_2019['Date'] = np.random.choice(date_range, size=len(ind_2019))

ind_2019 = ind_2019.sort_values('Date')

ind_2019['Date'] = pd.to_datetime(ind_2019['Date'], format='%Y-%m-%d')

# %%
ind_2019.set_index('Date',inplace=True)

# %%
mode_value = ind_2019['Founders'].mode()[0]
print(mode_value)

mode_value = ind_2019['HeadQuarter'].mode()[0]
print(mode_value)

mode_value = ind_2019['Stage'].mode()[0]
print(mode_value)
# Out:
# Vivek Gupta, Abhay Hanjura
# Bangalore
# Series A

# %%
ind_2019['HeadQuarter'] = ind_2019['HeadQuarter'].fillna(ind_2019['HeadQuarter'].mode()[0])
ind_2019['Stage'] = ind_2019['Stage'].fillna(ind_2019['Stage'].mode()[0])
ind_2019['Founders'] = ind_2019['Founders'].fillna(ind_2019['Founders'].mode()[0])

# %%
ind_2019['HeadQuarter'] = ind_2019['HeadQuarter'].str.replace('New Delhi', 'Delhi')

# %%
unique_values = ind_2019['HeadQuarter'].unique()
print(unique_values)
# Out:
# ['Bangalore' 'Mumbai' 'Gurugram' 'Ahmedabad' 'Delhi' 'Noida' 'Pune'
#  'Hyderabad' 'Haryana' 'Chennai' 'Jaipur' 'Telangana' 'Chandigarh'
#  'Rajasthan' 'Uttar pradesh' 'Surat']

# %% [markdown]
# ## Using Statiscal means to fill the missing values in the founded column

# %%
ind_2019['Founded'] = pd.to_numeric(ind_2019['Founded'], errors='coerce')

# %%
ind_2019['Founded'] = ind_2019['Founded'].fillna(0)

# %%
plt.hist(ind_2019['Founded'], bins=20)
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.ylabel('Frequency')
plt.show()

# %%
ind_2019['Founded'].replace(0, np.nan, inplace=True)

# %%
ind_2019.isna().sum()
# Out:
# Company/Brand     0
# Founded          29
# HeadQuarter       0
# Sector            0
# Founders          0
# Investor          0
# Amount($)         0
# Stage             0
# Year              0
# dtype: int64

# %%
ind_2019['Founded'].fillna(ind_2019['Founded'].median(), inplace=True)

# %%
ind_2019['Founded'] = ind_2019['Founded'].astype(int)

# %% [markdown]
# ## Restructuring the shape of the column & using statistical means to fill them, Restructuring the name convention of the sector column by containing it in a list of substrings and assigning it to name.

# %%
import pandas as pd
import numpy as np

ind_2019 = pd.DataFrame({
    'Sector': ['Tech', 'Finance', '—', 'Retail', 'Healthcare'],
    'Revenue': [10000, 5000, np.nan, 8000, 7000],
    'Year': [np.nan, 2019, np.nan, 2019, 2019]
})

ind_2019['Sector'].replace({'—': np.nan}, inplace=True)

# %%
import pandas as pd

ind_2019 = pd.DataFrame({
    'Sector': ['Tech', 'Finance', 'Healthcare', 'Retail'],
    'Amount($)': ['10,000', '5000.50', '2000.00', 'NaN', '(100)']
})

ind_2019['Amount($)'] = ind_2019['Amount($)'].str.replace('[^\d\.]', '')
ind_2019['Amount($)'] = pd.to_numeric(ind_2019['Amount($)'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 import pandas as pd
# ----> 3 ind_2019 = pd.DataFrame({
#       4     'Sector': ['Tech', 'Finance', 'Healthcare', 'Retail'],
#       5     'Amount($)': ['10,000', '5000.50', '2000.00', 'NaN', '(100)']
#       6 })
#       8 ind_2019['Amount($)'] = ind_2019['Amount($)'].str.replace('[^\d\.]', '')
#       9 ind_2019['Amount($)'] = pd.to_numeric(ind_2019['Amount($)'], errors='coerce')
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
ind_2019['Amount($)'] = ind_2019['Amount($)'].str.replace('[^\d\.]', '')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Amount($)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 ind_2019['Amount($)'] = ind_2019['Amount($)'].str.replace('[^\d\.]', '')
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Amount($)'

# %%
import pandas as pd

ind_2019 = pd.DataFrame({
    'Sector': ['Tech', 'Finance', 'Healthcare', 'Retail'],
    'Amount($)': ['10000', '5000', '2000', 'NaN']
})

ind_2019['Amount($)'] = pd.to_numeric(ind_2019['Amount($)'], errors='coerce')

# %%
import pandas as pd

ind_2019 = pd.DataFrame({
    'Sector': ['Tech', 'Finance', 'Healthcare', 'Retail'],
    'Amount($)': ['10,000', '5000.50', '2000.00', '(100)']
})

ind_2019['Amount($)'] = pd.to_numeric(ind_2019['Amount($)'], errors='coerce')

# %%
ind_2019.head()
# Out:
#        Sector  Amount($)
# 0        Tech    10000.0
# 1     Finance     5000.0
# 2  Healthcare     2000.0
# 3      Retail        NaN

# %%
ind_2019.isna().sum()
# Out:
# Sector       0
# Amount($)    2
# dtype: int64

# %%
# Create a histogram of the 'Amount' column
plt.hist(ind_2019['Amount($)'], bins=20)
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.ylabel('Frequency')
plt.show()

# %%
ind_2019['Amount($)'] = ind_2019['Amount($)'].fillna(ind_2019['Amount($)'].median())

# %%
ind_2019['Amount($)'] = ind_2019['Amount($)'].astype(int)

# %%
ind_2019.head()
# Out:
#        Sector  Amount($)
# 0        Tech        NaN
# 1     Finance     5000.5
# 2  Healthcare     2000.0
# 3      Retail        NaN

# %%
ind_2019.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# dtype: int64

# %%
# # Create a list of substrings to search for in the Sector column
tech = ['Mobile','Technology', 'Internet', 'Software', 'Hardware','SaaS','Blockchain','Apps','Information Services','SEM',
        'Artificial Intelligence','CleanTech','Aerospace','Robotics','Ai','PaaS','Medtech','Agritech','HR tech',
       'Tech','FoodTech','Safety tech','IoT','Legal tech','Infratech','Netwokring platform','Telecommunication','Cloud','Aero',
       'Virtual','Content','Photonics','app','Proptech','Deeptech','AR','VR','Agri tech','-Tech','AgriTech','IT','Network',
        'Data','HrTech','Foodtech','Spacetech','E-mobility','Automation','Logitech','HRTech','Drone','MLOps','Innovation',
       'BioTechnology','TaaS','network','equipment','SpaceTech','CRM','MarTech','Nanotechnology','Femtech','startup','AI']
fin = ['Lending','Finance','Insurance', 'Payments','Financial Services','Credit','Credit Cards','Mutual Funds',
       'Banking','Escrow','Venture','financial','Taxation','Capital','firm','Equity']
fint = ['NFT','Virtual Banking','FinTech','Fintech','Cryptocurrency','Crypto','Insurtech','InsurTech']
health = ['Health', 'Medical','Pharmaceutical','Health Diagnotics','Health Care','Hospital','Biotechnology','Biopharma',
         'Hygiene management','HealthTech','Healthcare','HealthCare','laboratory','Biotech','Healthtech','HeathTech',
         'Helathcare','Veterinary']
mkt = ['Brand Marketing','Marketing','Event Promotion','Market']
agric = ['Farming','Agriculture','Nutrition','Hauz Khas','Fishery']
con = ['Food','Food and Beverages','Dairy','Beverages','Beer','FMCG']
econ = ['B2B','Shopping','E-Commerce','Trading Platform','E-commerce','E-marketplace','marketplace','e-commerce','Ecommerce',
        'E-market','Commerce','Trading platform']
cons = ['Wholesale','Consumer','Shoes','Packaging','Retail','Consulting','Food Delivery']
edu = ['E-Learning','EdTech','Education','Communities','Edtech','Preschool','School']
welln = ['Lifestyle','Beauty','Wellness','Cosmetics','Yoga','Skincare','D2C','Fitness','Lifestyle','Training']
real_est=['Real Estate','Home Decor','Accomodation','Interior design','Home Design','Home interior','Co-living',
          'Construction']
log = ['Logistics','Rental','Tourism','Travel','TravelTech','Transport','Transportation','Aviation','Mobility']

auto = ['Automotive','Electric vehicle','Industrial Automation','Vehicles','Automotive tech','Automobile','Tyre','car','Car',
       'Vehicle','Mechanical']
manu = ['Manufacturing']
ener = ['Renewable Energy','Solar','Energy','Energy Storage','Battery','Oil and Gas','Renewable','EV','Electricity',
       'purification','Renewables']
medi = ['Entertainment','Media','News','Video','Digital Media','FM','Publication','OTT','Social Network','Music',
        'Digital platform','Podcast','publishing','Blogging']
game = ['Gaming','Games','Sports']

style = ['Fashion','Jewelry','Eyeglasses','Eye Wear','Apparel','Dating','Celebrity','Eyewear','D2C Fashion','Matrimony',
         'Textiles','D2C jewellery','Foootwear','Arts']
hos =['Hospitality','Hotel','Leisure']


ind_2019['Sector_clean'] = 'Other'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(tech)), 'Sector_clean'] = 'Technology'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(fin)), 'Sector_clean'] = 'Finance'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(health)), 'Sector_clean'] = 'Healthcare'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(mkt)), 'Sector_clean'] = 'Marketing'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(agric)), 'Sector_clean'] = 'Agriculture'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(econ)), 'Sector_clean'] = 'E-Commerce'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(edu)), 'Sector_clean'] = 'Education'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(welln)), 'Sector_clean'] = 'Wellness/Beauty'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(real_est)), 'Sector_clean'] = 'Real Estate'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(log)), 'Sector_clean'] = 'Logistics'

ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(auto)), 'Sector_clean'] = 'Automotive'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(manu)), 'Sector_clean'] = 'Manufacture'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(ener)), 'Sector_clean'] = 'Energy'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(medi)), 'Sector_clean'] = 'Media/Entertainment'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(hos)), 'Sector_clean'] = 'Hospitality'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(style)), 'Sector_clean'] = 'Lifestyle'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(cons)), 'Sector_clean'] = 'Consumer Services'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(game)), 'Sector_clean'] = 'Gaming'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(fint)), 'Sector_clean'] = 'FinTech'
ind_2019.loc[ind_2019['Sector'].str.contains('|'.join(con)), 'Sector_clean'] = 'Consumables'

# %%
ind_2019.drop('Sector',axis=1,inplace=True)

# %%
ind_2019= ind_2019.rename(columns={'Sector_clean': 'Sector'})

# %%
ind_2019.head()
# Out:
#            Company/Brand  Founded HeadQuarter  \
# Date
# 2019-01-04        Phable     2018   Bangalore
# 2019-01-09         Credr     2014      Mumbai
# 2019-01-18           Oyo     2013    Gurugram
# 2019-01-25        Rivigo     2014   Bangalore
# 2019-01-26  Freightwalla     2017      Mumbai
#
#                                            Founders  \
# Date
# 2019-01-04                              Sumit Sinha
# 2019-01-09                                   Mittal
# 2019-01-18                           Ritesh Agarwal
# 2019-01-25                 Deepak Garg, Gazal Kalra
# 2019-01-26  Sanjay Bhatia, Bharat Tanvi, Punit Java
#
#                                                      Investor  Amount($)  \
# Date
# 2019-01-04  LetsVenture, 91 Springboard, IKP Knowledge, An...     220000
# 2019-01-09  Omidyar Network, Eight Roads Ventures, GrowthS...    6000000
# 2019-01-18  MyPreferred Transformation, Avendus Finance, S...  693000000
# 2019-01-25  SAIF Partners India VI Ltd, Spring Canter Inve...   20000000
# 2019-01-26                  Amplo, FJ Labs, Rogue One Capital    4000000
#
#                Stage  Year       Sector
# Date
# 2019-01-04  Series A  2019   Healthcare
# 2019-01-09  Series A  2019   Automotive
# 2019-01-18  Series A  2019  Hospitality
# 2019-01-25  Series F  2019    Logistics
# 2019-01-26  Series A  2019   E-Commerce

# %% [markdown]
# ## Ploting Visuals to check the shape of the dataframe

# %%
if ind_2019.empty:
    print("No data found for the year 2019")
else:
    # Calculate the total funding by sector
    total_funding_by_sector = ind_2019.groupby('Sector')['Amount($)'].sum().reset_index()

    top_10_sectors = total_funding_by_sector.sort_values(by='Amount($)', ascending=False).head(10)

    ax = sns.barplot(data=top_10_sectors, x='Sector', y='Amount($)')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    plt.show()

# %%
# Get the top ten headquarters
top_ten_hq = ind_2019['HeadQuarter'].value_counts().nlargest(10)

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(top_ten_hq.index, top_ten_hq.values, color='blue')
plt.title('Top Ten Headquarters in ind_2019')
plt.xlabel('Headquarters')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 2020

# %% [markdown]
# ## Checking the shape of the data,Replace missing values and dropping,adding a date series

# %%
ind_2020.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount($)     Stage Unnamed: 9
# 0                      Angel investors     $200,000       NaN        NaN
# 1                      GSF Accelerator     $100,000  Pre-seed        NaN
# 2                       Venture Center  Undisclosed  Pre-seed        NaN
# 3  Venture Catalysts, PointOne Capital     $400,000       NaN        NaN
# 4  Siana Capital Management, Info Edge     $340,000       NaN        NaN

# %%
ind_2020.describe()
# Out:
#        Company/Brand Founded HeadQuarter   Sector  \
# count           1055     843         961     1042
# unique           905      27          77      302
# top            Nykaa    2015   Bangalore  Fintech
# freq               6     136         317       80
#
#                             What it does       Founders           Investor  \
# count                               1055           1043               1017
# unique                               990            927                848
# top     Provides online learning classes  Falguni Nayar  Venture Catalysts
# freq                                   4              6                 20
#
#           Amount($)     Stage Unnamed: 9
# count          1052       591          2
# unique          309        42          2
# top     Undisclosed  Series A   Pre-Seed
# freq            243        96          1

# %%
ind_2020['Sector'].replace('—', pd.np.nan, inplace=True)

ind_2020['Year']=2020

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand       0
# Founded           212
# HeadQuarter        94
# Sector             13
# What it does        0
# Founders           12
# Investor           38
# Amount($)           3
# Stage             464
# Unnamed: 9       1053
# Year                0
# dtype: int64

# %%
ind_2020.loc[518, 'Sector'] = 'E-Commerce'
ind_2020.loc[569, 'Sector'] = 'E-Commerce'
ind_2020.loc[687, 'Sector'] = 'Social Work'
ind_2020.loc[699, 'Sector'] = 'Beauty&Wellness'
ind_2020.loc[707, 'Sector'] = 'E-Commerce'
ind_2020.loc[732, 'Sector'] = 'Technology'
ind_2020.loc[746, 'Sector'] = 'E-Commerce'
ind_2020.loc[763, 'Sector'] = 'E-Commerce'
ind_2020.loc[746, 'Sector'] = 'E-Commerce'
ind_2020.loc[809, 'Sector'] = 'Technology'
ind_2020.loc[918, 'Sector'] = 'Fintech'
ind_2020.loc[926, 'Sector'] = 'Real Estate'
ind_2020.loc[1012, 'Sector'] = 'Technology'
ind_2020.loc[1031, 'Sector'] = 'Technology'
ind_2020.loc[746, 'Sector'] = 'E-Commerce'

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand       0
# Founded           212
# HeadQuarter        94
# Sector              0
# What it does        0
# Founders           12
# Investor           38
# Amount($)           3
# Stage             464
# Unnamed: 9       1053
# Year                0
# dtype: int64

# %%
ind_2020.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1050    False
# 1051    False
# 1052    False
# 1053    False
# 1054    False
# Length: 1055, dtype: bool

# %%
ind_2020.drop_duplicates(inplace=True)

# %%
# create a DatetimeIndex with dates for the entire year
date_range = pd.date_range(start='2020-01-01', end='2020-12-31', freq='D')

# create a new column 'Date' with random dates within the year 2018
ind_2020['Date'] = np.random.choice(date_range, size=len(ind_2020))

ind_2020 = ind_2020.sort_values('Date')

ind_2020['Date'] = pd.to_datetime(ind_2020['Date'], format='%Y-%m-%d')

# %%
ind_2020.set_index('Date',inplace=True)

# %% [markdown]
# ## Filling & replacing val in the HQ col using dictionary then filling in missing values for dif col, using substrings to alter some rows

# %%
cities_to_replace = ["Tirunelveli, Tamilnadu", "Frisco, Texas, United States", "Dhingsara, Haryana", "New York, United States",
"Jaipur, Rajastan", "Jaipur, Rajastan", "San Francisco, California, United States", "San Francisco, United States", 
 "San Ramon, California", "Paris, Ile-de-France, France", "Plano, Texas, United States",
"San Francisco Bay Area, Silicon Valley,West Coast", "London, England, United Kingdom", "Sydney, New South Wales, Australia", 
"Milano, Lombardia, Italy", "New York, United States", "Palmwoods, Queensland, Australia", "London, England, United Kingdom", 
"San Francisco Bay Area, West Coast, Western US", "Trivandrum, Kerala, India", "Samastipur, Bihar",
"Irvine, California, United States", "Tumkur, Karnataka", "San Francisco Bay Area, Silicon Valley, West Coast", 
"San Francisco, California, United States", "Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom", "Shanghai, China", 
"Jiaxing, Zhejiang, China", "Tangerang, Jawa Barat, Indonesia"]

new_cities = ['Tamilnadu', 'Texas', 'Haryana', 'New York', 'Rajastan', 'Rajastan', 'San Francisco', 'San Francisco', 
'San Ramon', 'Paris', 'Texas', 'San Francisco', 'London', 'Sydney', 'Milano', 'New York', 'Queensland', 'London', 
'San Francisco', 'Kerala', 'Biphar', 'California', 'Karnataka', 'San Francisco', 'San Francisco', 'Newcastle', 'Shanghai', 
'Jiaxing', 'Jawa Barat']

for city, new_city in zip(cities_to_replace, new_cities):
    ind_2020['HeadQuarter'] = ind_2020['HeadQuarter'].apply(lambda x: new_city if city in str(x) else x)

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand       0
# Founded           212
# HeadQuarter        94
# Sector              0
# What it does        0
# Founders           12
# Investor           38
# Amount($)           3
# Stage             462
# Unnamed: 9       1050
# Year                0
# dtype: int64

# %%
ind_2020.head()
# Out:
#              Company/Brand Founded HeadQuarter      Sector  \
# Date
# 2020-01-01  Muse Wearables    2018     Chennai        Tech
# 2020-01-02          Pickrr    2015   New Delhi   Logistics
# 2020-01-02      Kristal AI    2016         NaN          AI
# 2020-01-02         Hapramp    2018    Gurugram  Blockchain
# 2020-01-03          Tricog    2015   Bangalore  Healthtech
#
#                                                  What it does  \
# Date
# 2020-01-01  It sells the world’s first payment-enabled hyb...
# 2020-01-02  Pickrr is an on-demand first mile logistics co...
# 2020-01-02        Provides Algorithm-based financial services
# 2020-01-02  Startup working on technologies like blockchai...
# 2020-01-03  Provides virtual cardiology services through i...
#
#                                                      Founders  \
# Date
# 2020-01-01  K.L.N Sai Prasanth, Yathindra Ajay K.A, K. Pra...
# 2020-01-02    Ankit Kaushik, Gaurav Mangla, Rhitiman Majumder
# 2020-01-02                 Asheesh Chanda, Vineeth Narasimhan
# 2020-01-02                     Shubhendra Vikram, Ankit Kumar
# 2020-01-03  Charit Bhograj, Zainul Charbiwala, Udayan Dasg...
#
#                                                      Investor    Amount($)  \
# Date
# 2020-01-01                          Dr. Bhaskar Rao Bollineni   $3,000,000
# 2020-01-02                                           Swastika   $4,000,000
# 2020-01-02                                  Chiratae Ventures   $6,000,000
# 2020-01-02                                     Anand Mahindra   $1,000,000
# 2020-01-03  UTEC-The University of Tokyo Edge Capital, Afl...  $10,500,000
#
#                Stage Unnamed: 9  Year
# Date
# 2020-01-01       NaN        NaN  2020
# 2020-01-02       NaN        NaN  2020
# 2020-01-02  Series A        NaN  2020
# 2020-01-02       NaN        NaN  2020
# 2020-01-03  Series B        NaN  2020

# %%
mode_value = ind_2020['Founders'].mode()[0]
print(mode_value)

mode_value = ind_2020['Stage'].mode()[0]
print(mode_value)

mode_value = ind_2020['Investor'].mode()[0]
print(mode_value)

mode_value = ind_2020['HeadQuarter'].mode()[0]
print(mode_value)
# Out:
# Byju Raveendran
# Series A
# Venture Catalysts
# Bangalore

# %%
ind_2020['Founders'] = ind_2020['Founders'].fillna(ind_2020['Founders'].mode()[0])
ind_2020['Stage'] = ind_2020['Stage'].fillna(ind_2020['Stage'].mode()[0])
ind_2020['Investor'] = ind_2020['Investor'].fillna(ind_2020['Investor'].mode()[0])
ind_2020['HeadQuarter'] = ind_2020['HeadQuarter'].fillna(ind_2020['HeadQuarter'].mode()[0])

# %%
ind_2020['HeadQuarter'] = ind_2020['HeadQuarter'].str.replace('New Delhi', 'Delhi')
ind_2020['HeadQuarter'] = ind_2020['HeadQuarter'].str.replace('Banglore', 'Bangalore')
ind_2020['HeadQuarter'] = ind_2020['HeadQuarter'].str.replace('Gurgaon', 'Gurugram')

# %%
unique_values = ind_2020['HeadQuarter'].unique()
print(unique_values)
# Out:
# ['Chennai' 'Delhi' 'Bangalore' 'Gurugram' 'Kolkata' 'Seoul' 'Hyderabad'
#  'Bengaluru' 'Mumbai' 'Pune' 'Kerala' 'Singapore' 'Thane' 'Indore'
#  'Ahmedabad' 'London' 'Bangaldesh' 'California' 'Gujarat' 'Queensland'
#  'Belgaum' 'Noida' 'San Ramon' 'Chandigarh' 'Haryana' 'San Francisco'
#  'Jodhpur' 'Tamil Nadu' 'Bihar' 'Texas' 'Kanpur' 'France' 'Hyderebad'
#  'Andheri' 'New York' 'Sydney' 'Goa' 'Jaipur' 'San Franciscao' 'Kochi'
#  'Dehradun' 'Rajastan' 'Uttar Pradesh' 'Karnataka' 'Bhopal' 'Tamilnadu'
#  'Cochin' 'Shanghai' 'Riyadh' 'Milano' 'Berlin' 'Paris' 'Jawa Barat'
#  'Warangal' 'Newcastle' 'Coimbatore' 'Patna' 'Ludhiana' 'Bangkok' 'Odisha'
#  'Biphar' 'Seattle' 'Jiaxing']

# %%
seedr = ['seed round','Seed round','Seed Round',]
preser= ['Pre Series A','Pre series A','Pre-series A','Pre-Series A']

ind_2020.loc[ind_2020['Stage'].str.contains('|'.join(seedr)), 'Stage'] = 'Seed Round'
ind_2020.loc[ind_2020['Stage'].str.contains('|'.join(preser)), 'Stage'] = 'Pre-series A'

# %%
ind_2020['Founded'] = pd.to_numeric(ind_2020['Founded'], errors='coerce')

ind_2020['Founded'] = ind_2020['Founded'].fillna(0)

# %%
plt.hist(ind_2020['Founded'], bins=20)
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(ind_2020['Founded'].dropna())
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.show()

# %%
ind_2020['Founded'].replace(0, np.nan, inplace=True)

# %%
ind_2020['Founded'].fillna(ind_2020['Founded'].median(), inplace=True)

ind_2020['Founded'] = ind_2020['Founded'].astype(int)

# %%
ind_2020.head()
# Out:
#              Company/Brand  Founded HeadQuarter      Sector  \
# Date
# 2020-01-01  Muse Wearables     2018     Chennai        Tech
# 2020-01-02          Pickrr     2015       Delhi   Logistics
# 2020-01-02      Kristal AI     2016   Bangalore          AI
# 2020-01-02         Hapramp     2018    Gurugram  Blockchain
# 2020-01-03          Tricog     2015   Bangalore  Healthtech
#
#                                                  What it does  \
# Date
# 2020-01-01  It sells the world’s first payment-enabled hyb...
# 2020-01-02  Pickrr is an on-demand first mile logistics co...
# 2020-01-02        Provides Algorithm-based financial services
# 2020-01-02  Startup working on technologies like blockchai...
# 2020-01-03  Provides virtual cardiology services through i...
#
#                                                      Founders  \
# Date
# 2020-01-01  K.L.N Sai Prasanth, Yathindra Ajay K.A, K. Pra...
# 2020-01-02    Ankit Kaushik, Gaurav Mangla, Rhitiman Majumder
# 2020-01-02                 Asheesh Chanda, Vineeth Narasimhan
# 2020-01-02                     Shubhendra Vikram, Ankit Kumar
# 2020-01-03  Charit Bhograj, Zainul Charbiwala, Udayan Dasg...
#
#                                                      Investor    Amount($)  \
# Date
# 2020-01-01                          Dr. Bhaskar Rao Bollineni   $3,000,000
# 2020-01-02                                           Swastika   $4,000,000
# 2020-01-02                                  Chiratae Ventures   $6,000,000
# 2020-01-02                                     Anand Mahindra   $1,000,000
# 2020-01-03  UTEC-The University of Tokyo Edge Capital, Afl...  $10,500,000
#
#                Stage Unnamed: 9  Year
# Date
# 2020-01-01  Series A        NaN  2020
# 2020-01-02  Series A        NaN  2020
# 2020-01-02  Series A        NaN  2020
# 2020-01-02  Series A        NaN  2020
# 2020-01-03  Series B        NaN  2020

# %%
ind_2020.drop('What it does',axis=1,inplace=True)

# %%
ind_2020.drop('Unnamed: 9',axis=1,inplace=True)

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        3
# Stage            0
# Year             0
# dtype: int64

# %%
ind_2020.head(50)
# Out:
#                      Company/Brand  Founded HeadQuarter                Sector  \
# Date
# 2020-01-01          Muse Wearables     2018     Chennai                  Tech
# 2020-01-02                  Pickrr     2015       Delhi             Logistics
# 2020-01-02              Kristal AI     2016   Bangalore                    AI
# 2020-01-02                 Hapramp     2018    Gurugram            Blockchain
# 2020-01-03                  Tricog     2015   Bangalore            Healthtech
# 2020-01-03  Ola Financial Services     2016   Bangalore               Fintech
# 2020-01-03                NoBroker     2014   Bangalore           Real Estate
# 2020-01-03                Furlenco     2011   Bangalore             Ecommerce
# 2020-01-04               Smallcase     2015   Bangalore               FinTech
# 2020-01-05                FrontRow     2016   Bangalore                EdTech
# 2020-01-05              BankBazaar     2008     Chennai               Fintech
# 2020-01-06                 Zetwerk     2018   Bangalore           Marketplace
# 2020-01-07            Euler Motors     2016       Delhi       Automotive tech
# 2020-01-07                Livspace     2014   Bangalore           Home Design
# 2020-01-07                 Agnikul     2016     Chennai             Spacetech
# 2020-01-08           Omatra Hotels     2017     Kolkata           Hospitality
# 2020-01-08                DillyHub     2018       Seoul           Publication
# 2020-01-08               ChitMonks     2016   Hyderabad               Fintech
# 2020-01-09             Paytm money     2010   Bangalore               Fintech
# 2020-01-09                 Zetwerk     2018   Bangalore           Marketplace
# 2020-01-09             IncubateHub     2016   Bengaluru              Tech hub
# 2020-01-10                  Byju's     2011   Bangalore                EdTech
# 2020-01-11               OM Bhakti     2016   Bangalore                  FMCG
# 2020-01-11            Finelistings     2015       Delhi    Luxury car startup
# 2020-01-11          Myelin Foundry     2019   Bangalore          Deep Tech AI
# 2020-01-11                  Shipsy     2015    Gurugram            AI Company
# 2020-01-12                   LAVAL     2016   Bangalore             Cosmetics
# 2020-01-14                 WakeFit     2016   Bangalore                Retail
# 2020-01-14            Pristyn Care     2018    Gurugram            HealthCare
# 2020-01-14             HomeCapital     2016      Mumbai               Fintech
# 2020-01-14                 Airmeet     2016   Bangalore    Media & Networking
# 2020-01-14                 Pitstop     2015   Bangalore           Car Service
# 2020-01-14                    EWar     2019   Bangalore                Gaming
# 2020-01-16                 Eduvanz     2016      Mumbai               Fintech
# 2020-01-16               VestSpace     2018        Pune             Spacetech
# 2020-01-16           MetaMerphoSys     2016        Pune  Insurance technology
# 2020-01-16             Genrobotics     2015      Kerala            AI startup
# 2020-01-17                    Box8     2011      Mumbai              Foodtech
# 2020-01-17     Sunstone Eduversity     2014    Gurugram                EdTech
# 2020-01-17              Expertrons     2019      Mumbai                EdTech
# 2020-01-17             Nova Credit     2016   Bangalore               Fintech
# 2020-01-17                  Qapita     2019   Singapore               FinTech
# 2020-01-17                   Traya     2016      Mumbai            HealthTech
# 2020-01-18            Infra.Market     2016       Thane           Real Estate
# 2020-01-18  Finaureus Technologies     2017        Pune               Fintech
# 2020-01-19   Anaxee Digital Runner     2016      Indore                  Tech
# 2020-01-19                     MPL     2018   Bangalore        Gaming startup
# 2020-01-19      Wobot Intelligence     2016       Delhi                    AI
# 2020-01-19            JetSynthesys     2012      Mumbai                  Tech
# 2020-01-19                  Monech     2016      Mumbai               Fintech
#
#                                                      Founders  \
# Date
# 2020-01-01  K.L.N Sai Prasanth, Yathindra Ajay K.A, K. Pra...
# 2020-01-02    Ankit Kaushik, Gaurav Mangla, Rhitiman Majumder
# 2020-01-02                 Asheesh Chanda, Vineeth Narasimhan
# 2020-01-02                     Shubhendra Vikram, Ankit Kumar
# 2020-01-03  Charit Bhograj, Zainul Charbiwala, Udayan Dasg...
# 2020-01-03                                   Bhavish Aggarwal
# 2020-01-03      Amit Kumar Agarwal, Akhil Gupta, Saurabh Garg
# 2020-01-03                              Ajith Mohan Karimpana
# 2020-01-04   Anugrah Shrivastava, Rohan Gupta, Vasanth Kamath
# 2020-01-05   Mikhil Raj, Shubhadit Sharma, Ishaan Preet Singh
# 2020-01-05           Adhil Shetty, Arjun Shetty, Rati Shetty,
# 2020-01-06  Amrit Acharya, Srinath Ramakkrushnan, Vishal C...
# 2020-01-07                                       Saurav Kumar
# 2020-01-07                   Anuj Srivastava, Ramakant Sharma
# 2020-01-07                               Srinath Ravichandran
# 2020-01-08                    NAVEED AHAMED, SYED SAQQA ABBAS
# 2020-01-08                                       Ji Cheol Ryu
# 2020-01-08                                     Pavan Adipuram
# 2020-01-09                               Vijay Shekhar Sharma
# 2020-01-09  Amrit Acharya, Srinath Ramakkrushnan, Vishal C...
# 2020-01-09                                    Rajiv Mukherjee
# 2020-01-10                   Byju Raveendran, Divya Gokulnath
# 2020-01-11                   Sridhar Joshi, Prashant Kulkarni
# 2020-01-11                                      Aneesh Mathur
# 2020-01-11  Dr Gopichand Katragadda, Ganesh Suryanarayanan...
# 2020-01-11       Dhruv Agrawal, Himanshu Gupta, Soham Chokshi
# 2020-01-12                                 Shrishti, Prithika
# 2020-01-14               Ankit Garg, Chaitanya Ramalingegowda
# 2020-01-14                          Harsimarbir (Harsh) Singh
# 2020-01-14                                     Lalit Menghani
# 2020-01-14            Lalit Mangal, Vinay Jaasti, Manoj Singh
# 2020-01-14                                 Mihir Mohan Mishra
# 2020-01-14                          Parth Chadha, Rahul Singh
# 2020-01-16                          Varun Chopra, Raheel Shah
# 2020-01-16                                 Arun Kumar Sureban
# 2020-01-16                          Amit Naik, Kewal Vargante
# 2020-01-16  Arun George, Nikhil NP, Rashid Bin Abdulla, Vi...
# 2020-01-17                             Amit Raj, Anshul Gupta
# 2020-01-17                       Ashish Munjal, Piyush Nangru
# 2020-01-17                                      Jatin Solanki
# 2020-01-17                                     Nicky Goulimis
# 2020-01-17    Ravi Ravulaparthi, Lakshman Gupta, Vamsee Mohan
# 2020-01-17                         Altaf Saiyed, Saloni Anand
# 2020-01-18                    Aaditya Sharda, Souvik Sengupta
# 2020-01-18                           Arindam Ghosh, U R Bhatt
# 2020-01-19                       Govind Agrawal, Arti Agrawal
# 2020-01-19             Sai Srinivas Kiran G, Shubham Malhotra
# 2020-01-19             Adit Chhabra, Tapan Dixit,Tanay Dixit.
# 2020-01-19                                       Rajan Navani
# 2020-01-19                                    Byju Raveendran
#
#                                                      Investor     Amount($)  \
# Date
# 2020-01-01                          Dr. Bhaskar Rao Bollineni    $3,000,000
# 2020-01-02                                           Swastika    $4,000,000
# 2020-01-02                                  Chiratae Ventures    $6,000,000
# 2020-01-02                                     Anand Mahindra    $1,000,000
# 2020-01-03  UTEC-The University of Tokyo Edge Capital, Afl...   $10,500,000
# 2020-01-03                                    Matrix Partners   $27,000,000
# 2020-01-03                                   General Atlantic   $30,000,000
# 2020-01-03                                 Chowdry Associates    $2,200,000
# 2020-01-04              Sequoia Capital India, Blume Ventures   $13,400,000
# 2020-01-05            Lightspeed, Elevation, Deepika Padukone    $3,200,000
# 2020-01-05                                        WSV Capital    $5,967,000
# 2020-01-06                                          Greenoaks   $21,000,000
# 2020-01-07                            Inventus III India Fund    $2,530,000
# 2020-01-07                 Mercer Investments, Nicholas Cator    $9,000,000
# 2020-01-07                                        pi Ventures    $3,148,000
# 2020-01-08                                             Capify   Undisclosed
# 2020-01-08                    Kakao Ventures, Shinhan Capital    $1,400,000
# 2020-01-08                             Unicorn India Ventures      $650,000
# 2020-01-09                               One97 Communications    $5,600,000
# 2020-01-09                                    InnoVen capital    $2,200,000
# 2020-01-09                                  Venture Catalysts   Undisclosed
# 2020-01-10              Owl Ventures, Tiger Global Management  $200,000,000
# 2020-01-11                                  Venture Catalysts   Undisclosed
# 2020-01-11                                           Justdial   Undisclosed
# 2020-01-11                                           Pratithi   Undisclosed
# 2020-01-11                         DTDC, Udaan Angel Partners    $6,000,000
# 2020-01-12                                        Jazal Group   Undisclosed
# 2020-01-14                                   Sequoia Capital.   $20,000,000
# 2020-01-14        Sequoia Capital India, Hummingbird Ventures   $11,000,000
# 2020-01-14                               Varanium NexGen Fund   Undisclosed
# 2020-01-14                                        Accel India    $3,000,000
# 2020-01-14     Clairvest Group, Ontario Centres of Excellence    $1,020,000
# 2020-01-14                       Jindal Steels, Jeet Banerjee   Undisclosed
# 2020-01-16                                      Sequoia India    $5,000,000
# 2020-01-16                                       Next Capital   $10,000,000
# 2020-01-16                                       Good Capital   Undisclosed
# 2020-01-16                             Unicorn India Ventures      $300,000
# 2020-01-17                IIFL Seed Ventures Fund, Menlo park    $4,000,000
# 2020-01-17                             Prime Venture Partners    $3,000,000
# 2020-01-17                     Rohit Chanana, Sukanta Ganguly   Undisclosed
# 2020-01-17  Kleiner Perkins, Canapi Ventures, Index Ventur...   $50,000,000
# 2020-01-17                    Alto Partners, Mission Holdings    $1,080,000
# 2020-01-17                    Kae Capital, Whiteboard Capital   Undisclosed
# 2020-01-18  Trifecta Capital Advisors, Nexus Venture Partners   $20,000,000
# 2020-01-18                                   Pinetree Capital   Undisclosed
# 2020-01-19                             Orios Venture Partners   Undisclosed
# 2020-01-19               Pegasus Tech Ventures, Base Partners    $5,000,000
# 2020-01-19                              Sequoia Capital India    $2,500,000
# 2020-01-19            Adar C. Poonawalla, Kris Gopalakrishnan   $40,000,000
# 2020-01-19                                    Angel investors       $12,700
#
#                    Stage  Year
# Date
# 2020-01-01      Series A  2020
# 2020-01-02      Series A  2020
# 2020-01-02      Series A  2020
# 2020-01-02      Series A  2020
# 2020-01-03      Series B  2020
# 2020-01-03      Series A  2020
# 2020-01-03      Series A  2020
# 2020-01-03      Series C  2020
# 2020-01-04      Series B  2020
# 2020-01-05          Seed  2020
# 2020-01-05     Series D1  2020
# 2020-01-06      Series C  2020
# 2020-01-07      Series A  2020
# 2020-01-07      Series D  2020
# 2020-01-07  Pre-series A  2020
# 2020-01-08          Seed  2020
# 2020-01-08          Seed  2020
# 2020-01-08  Pre-series A  2020
# 2020-01-09      Series A  2020
# 2020-01-09      Series A  2020
# 2020-01-09      Series A  2020
# 2020-01-10      Series A  2020
# 2020-01-11    Seed Round  2020
# 2020-01-11      Series A  2020
# 2020-01-11      Series A  2020
# 2020-01-11      Series A  2020
# 2020-01-12  Pre-series A  2020
# 2020-01-14      Series B  2020
# 2020-01-14      Series A  2020
# 2020-01-14      Series A  2020
# 2020-01-14      Series A  2020
# 2020-01-14      Series A  2020
# 2020-01-14  Pre-series A  2020
# 2020-01-16      Series A  2020
# 2020-01-16      Series A  2020
# 2020-01-16  Pre-series A  2020
# 2020-01-16      Series A  2020
# 2020-01-17      Series A  2020
# 2020-01-17      Series A  2020
# 2020-01-17      Series A  2020
# 2020-01-17      Series B  2020
# 2020-01-17          Seed  2020
# 2020-01-17          Seed  2020
# 2020-01-18      Series B  2020
# 2020-01-18  Pre-series A  2020
# 2020-01-19      Series A  2020
# 2020-01-19      Series A  2020
# 2020-01-19  Pre-series A  2020
# 2020-01-19      Series A  2020
# 2020-01-19    Seed Round  2020

# %% [markdown]
# ## Converting the structure of the amt col,filling missing val with stats data,creating a substring to structure the sector column

# %%
ind_2020['Amount($)'].replace('', pd.np.nan, inplace=True)
ind_2020['Amount($)'] = ind_2020['Amount($)'].replace('undisclosed', np.nan)

# %%
import pandas as pd
import numpy as np

ind_2020 = pd.DataFrame({
    'Sector': ['Tech', 'Finance', 'Healthcare', 'Retail'],
    'Amount($)': ['', 'undisclosed', '10000', '(100)']
})

ind_2020['Amount($)'] = ind_2020['Amount($)'].replace('', np.nan, inplace=True)
ind_2020['Amount($)'] = ind_2020['Amount($)'].replace('undisclosed', np.nan)

ind_2020['Amount($)'] = pd.to_numeric(ind_2020['Amount($)'], errors='coerce')

# %%
# if it is not already a string, convert it to string
if ind_2020['Amount($)'].dtype != 'object':
    ind_2020['Amount($)'] = ind_2020['Amount($)'].astype(str)

# # remove non-numeric characters from the 'Amount' column
ind_2020['Amount($)'] = ind_2020['Amount($)'].str.replace('[^\d\.]', '')

ind_2020['Amount($)'] = pd.to_numeric(ind_2020['Amount($)'])

# %%
ind_2020.head()
# Out:
#              Company/Brand  Founded HeadQuarter      Sector  \
# Date
# 2020-01-01  Muse Wearables     2018     Chennai        Tech
# 2020-01-02          Pickrr     2015       Delhi   Logistics
# 2020-01-02      Kristal AI     2016   Bangalore          AI
# 2020-01-02         Hapramp     2018    Gurugram  Blockchain
# 2020-01-03          Tricog     2015   Bangalore  Healthtech
#
#                                                      Founders  \
# Date
# 2020-01-01  K.L.N Sai Prasanth, Yathindra Ajay K.A, K. Pra...
# 2020-01-02    Ankit Kaushik, Gaurav Mangla, Rhitiman Majumder
# 2020-01-02                 Asheesh Chanda, Vineeth Narasimhan
# 2020-01-02                     Shubhendra Vikram, Ankit Kumar
# 2020-01-03  Charit Bhograj, Zainul Charbiwala, Udayan Dasg...
#
#                                                      Investor   Amount($)  \
# Date
# 2020-01-01                          Dr. Bhaskar Rao Bollineni   3000000.0
# 2020-01-02                                           Swastika   4000000.0
# 2020-01-02                                  Chiratae Ventures   6000000.0
# 2020-01-02                                     Anand Mahindra   1000000.0
# 2020-01-03  UTEC-The University of Tokyo Edge Capital, Afl...  10500000.0
#
#                Stage  Year
# Date
# 2020-01-01  Series A  2020
# 2020-01-02  Series A  2020
# 2020-01-02  Series A  2020
# 2020-01-02  Series A  2020
# 2020-01-03  Series B  2020

# %%
ind_2020['Amount($)'] = ind_2020['Amount($)'].fillna(0)

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# dtype: int64

# %%
plt.hist(ind_2020['Amount($)'], bins=20)
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(ind_2020['Amount($)'])
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.show()

# %%
ind_2020['Amount($)'].replace(0, np.nan, inplace=True)

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand      0
# Founded            0
# HeadQuarter        0
# Sector             0
# Founders           0
# Investor           0
# Amount($)        247
# Stage              0
# Year               0
# dtype: int64

# %%
ind_2020['Amount($)'].fillna(ind_2020['Amount($)'].median(), inplace=True)

ind_2020['Amount($)'] = ind_2020['Amount($)'].astype(int)

# %%
ind_2020.head()
# Out:
#              Company/Brand  Founded HeadQuarter      Sector  \
# Date
# 2020-01-01  Muse Wearables     2018     Chennai        Tech
# 2020-01-02          Pickrr     2015       Delhi   Logistics
# 2020-01-02      Kristal AI     2016   Bangalore          AI
# 2020-01-02         Hapramp     2018    Gurugram  Blockchain
# 2020-01-03          Tricog     2015   Bangalore  Healthtech
#
#                                                      Founders  \
# Date
# 2020-01-01  K.L.N Sai Prasanth, Yathindra Ajay K.A, K. Pra...
# 2020-01-02    Ankit Kaushik, Gaurav Mangla, Rhitiman Majumder
# 2020-01-02                 Asheesh Chanda, Vineeth Narasimhan
# 2020-01-02                     Shubhendra Vikram, Ankit Kumar
# 2020-01-03  Charit Bhograj, Zainul Charbiwala, Udayan Dasg...
#
#                                                      Investor  Amount($)  \
# Date
# 2020-01-01                          Dr. Bhaskar Rao Bollineni    3000000
# 2020-01-02                                           Swastika    4000000
# 2020-01-02                                  Chiratae Ventures    6000000
# 2020-01-02                                     Anand Mahindra    1000000
# 2020-01-03  UTEC-The University of Tokyo Edge Capital, Afl...   10500000
#
#                Stage  Year
# Date
# 2020-01-01  Series A  2020
# 2020-01-02  Series A  2020
# 2020-01-02  Series A  2020
# 2020-01-02  Series A  2020
# 2020-01-03  Series B  2020

# %%
# # Create a list of substrings to search for in the Sector column
tech = ['Mobile','Technology', 'Internet', 'Software', 'Hardware','SaaS','Blockchain','Apps','Information Services','SEM',
        'Artificial Intelligence','CleanTech','Aerospace','Robotics','Ai','PaaS','Medtech','Agritech','HR tech',
       'Tech','FoodTech','Safety tech','IoT','Legal tech','Infratech','Netwokring platform','Telecommunication','Cloud','Aero',
       'Virtual','Content','Photonics','app','Proptech','Deeptech','AR','VR','Agri tech','-Tech','AgriTech','IT','Network',
        'Data','HrTech','Foodtech','Spacetech','E-mobility','Automation','Logitech','HRTech','Drone','MLOps','Innovation',
       'BioTechnology','TaaS','network','equipment','SpaceTech','CRM','MarTech','Nanotechnology','Femtech','startup','AI']
fin = ['Lending','Finance','Insurance', 'Payments','Financial Services','Credit','Credit Cards','Mutual Funds',
       'Banking','Escrow','Venture','financial','Taxation','Capital','firm','Equity']
fint = ['NFT','Virtual Banking','FinTech','Fintech','Cryptocurrency','Crypto','Insurtech','InsurTech']
health = ['Health', 'Medical','Pharmaceutical','Health Diagnotics','Health Care','Hospital','Biotechnology','Biopharma',
         'Hygiene management','HealthTech','Healthcare','HealthCare','laboratory','Biotech','Healthtech','HeathTech',
         'Helathcare','Veterinary']
mkt = ['Brand Marketing','Marketing','Event Promotion','Market']
agric = ['Farming','Agriculture','Nutrition','Hauz Khas','Fishery']
con = ['Food','Food and Beverages','Dairy','Beverages','Beer','FMCG','Beverage']
econ = ['B2B','Shopping','E-Commerce','Trading Platform','E-commerce','E-marketplace','marketplace','e-commerce','Ecommerce',
        'E-market','Commerce','Trading platform']
cons = ['Wholesale','Consumer','Shoes','Packaging','Retail','Consulting','Food Delivery']
edu = ['E-Learning','EdTech','Education','Communities','Edtech','Preschool','School']
welln = ['Lifestyle','Beauty','Wellness','Cosmetics','Yoga','Skincare','D2C','Fitness','Lifestyle','Training']
real_est=['Real Estate','Home Decor','Accomodation','Interior design','Home Design','Home interior','Co-living',
          'Construction']
log = ['Logistics','Rental','Tourism','Travel','TravelTech','Transport','Transportation','Aviation','Mobility']

auto = ['Automotive','Electric vehicle','Industrial Automation','Vehicles','Automotive tech','Automobile','Tyre','car','Car',
       'Vehicle','Mechanical']
manu = ['Manufacturing']
ener = ['Renewable Energy','Solar','Energy','Energy Storage','Battery','Oil and Gas','Renewable','EV','Electricity',
       'purification','Renewables']
medi = ['Entertainment','Media','News','Video','Digital Media','FM','Publication','OTT','Social Network','Music',
        'Digital platform','Podcast','publishing','Blogging']
game = ['Gaming','Games','Sports']

style = ['Fashion','Jewelry','Eyeglasses','Eye Wear','Apparel','Dating','Celebrity','Eyewear','D2C Fashion','Matrimony',
         'Textiles','D2C jewellery','Foootwear','Arts']
hos =['Hospitality','Hotel','Leisure']


ind_2020['Sector_clean'] = 'Other'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(tech)), 'Sector_clean'] = 'Technology'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(fin)), 'Sector_clean'] = 'Finance'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(health)), 'Sector_clean'] = 'Healthcare'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(mkt)), 'Sector_clean'] = 'Marketing'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(agric)), 'Sector_clean'] = 'Agriculture'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(econ)), 'Sector_clean'] = 'E-Commerce'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(edu)), 'Sector_clean'] = 'Education'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(welln)), 'Sector_clean'] = 'Wellness/Beauty'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(real_est)), 'Sector_clean'] = 'Real Estate'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(log)), 'Sector_clean'] = 'Logistics'

ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(auto)), 'Sector_clean'] = 'Automotive'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(manu)), 'Sector_clean'] = 'Manufacture'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(ener)), 'Sector_clean'] = 'Energy'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(medi)), 'Sector_clean'] = 'Media/Entertainment'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(hos)), 'Sector_clean'] = 'Hospitality'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(style)), 'Sector_clean'] = 'Lifestyle'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(cons)), 'Sector_clean'] = 'Consumer Services'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(game)), 'Sector_clean'] = 'Gaming'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(fint)), 'Sector_clean'] = 'FinTech'
ind_2020.loc[ind_2020['Sector'].str.contains('|'.join(con)), 'Sector_clean'] = 'Consumables'

# %%
ind_2020.head()
# Out:
#              Company/Brand  Founded HeadQuarter      Sector  \
# Date
# 2020-01-01  Muse Wearables     2018     Chennai        Tech
# 2020-01-02          Pickrr     2015       Delhi   Logistics
# 2020-01-02      Kristal AI     2016   Bangalore          AI
# 2020-01-02         Hapramp     2018    Gurugram  Blockchain
# 2020-01-03          Tricog     2015   Bangalore  Healthtech
#
#                                                      Founders  \
# Date
# 2020-01-01  K.L.N Sai Prasanth, Yathindra Ajay K.A, K. Pra...
# 2020-01-02    Ankit Kaushik, Gaurav Mangla, Rhitiman Majumder
# 2020-01-02                 Asheesh Chanda, Vineeth Narasimhan
# 2020-01-02                     Shubhendra Vikram, Ankit Kumar
# 2020-01-03  Charit Bhograj, Zainul Charbiwala, Udayan Dasg...
#
#                                                      Investor  Amount($)  \
# Date
# 2020-01-01                          Dr. Bhaskar Rao Bollineni    3000000
# 2020-01-02                                           Swastika    4000000
# 2020-01-02                                  Chiratae Ventures    6000000
# 2020-01-02                                     Anand Mahindra    1000000
# 2020-01-03  UTEC-The University of Tokyo Edge Capital, Afl...   10500000
#
#                Stage  Year Sector_clean
# Date
# 2020-01-01  Series A  2020   Technology
# 2020-01-02  Series A  2020    Logistics
# 2020-01-02  Series A  2020   Technology
# 2020-01-02  Series A  2020   Technology
# 2020-01-03  Series B  2020   Healthcare

# %%
ind_2020.drop('Sector',axis=1,inplace=True)

# %%
ind_2020= ind_2020.rename(columns={'Sector_clean': 'Sector'})

# %%
ind_2020.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# Sector           0
# dtype: int64

# %%
ind_2020.head(50)
# Out:
#                      Company/Brand  Founded HeadQuarter  \
# Date
# 2020-01-01          Muse Wearables     2018     Chennai
# 2020-01-02                  Pickrr     2015       Delhi
# 2020-01-02              Kristal AI     2016   Bangalore
# 2020-01-02                 Hapramp     2018    Gurugram
# 2020-01-03                  Tricog     2015   Bangalore
# 2020-01-03  Ola Financial Services     2016   Bangalore
# 2020-01-03                NoBroker     2014   Bangalore
# 2020-01-03                Furlenco     2011   Bangalore
# 2020-01-04               Smallcase     2015   Bangalore
# 2020-01-05                FrontRow     2016   Bangalore
# 2020-01-05              BankBazaar     2008     Chennai
# 2020-01-06                 Zetwerk     2018   Bangalore
# 2020-01-07            Euler Motors     2016       Delhi
# 2020-01-07                Livspace     2014   Bangalore
# 2020-01-07                 Agnikul     2016     Chennai
# 2020-01-08           Omatra Hotels     2017     Kolkata
# 2020-01-08                DillyHub     2018       Seoul
# 2020-01-08               ChitMonks     2016   Hyderabad
# 2020-01-09             Paytm money     2010   Bangalore
# 2020-01-09                 Zetwerk     2018   Bangalore
# 2020-01-09             IncubateHub     2016   Bengaluru
# 2020-01-10                  Byju's     2011   Bangalore
# 2020-01-11               OM Bhakti     2016   Bangalore
# 2020-01-11            Finelistings     2015       Delhi
# 2020-01-11          Myelin Foundry     2019   Bangalore
# 2020-01-11                  Shipsy     2015    Gurugram
# 2020-01-12                   LAVAL     2016   Bangalore
# 2020-01-14                 WakeFit     2016   Bangalore
# 2020-01-14            Pristyn Care     2018    Gurugram
# 2020-01-14             HomeCapital     2016      Mumbai
# 2020-01-14                 Airmeet     2016   Bangalore
# 2020-01-14                 Pitstop     2015   Bangalore
# 2020-01-14                    EWar     2019   Bangalore
# 2020-01-16                 Eduvanz     2016      Mumbai
# 2020-01-16               VestSpace     2018        Pune
# 2020-01-16           MetaMerphoSys     2016        Pune
# 2020-01-16             Genrobotics     2015      Kerala
# 2020-01-17                    Box8     2011      Mumbai
# 2020-01-17     Sunstone Eduversity     2014    Gurugram
# 2020-01-17              Expertrons     2019      Mumbai
# 2020-01-17             Nova Credit     2016   Bangalore
# 2020-01-17                  Qapita     2019   Singapore
# 2020-01-17                   Traya     2016      Mumbai
# 2020-01-18            Infra.Market     2016       Thane
# 2020-01-18  Finaureus Technologies     2017        Pune
# 2020-01-19   Anaxee Digital Runner     2016      Indore
# 2020-01-19                     MPL     2018   Bangalore
# 2020-01-19      Wobot Intelligence     2016       Delhi
# 2020-01-19            JetSynthesys     2012      Mumbai
# 2020-01-19                  Monech     2016      Mumbai
#
#                                                      Founders  \
# Date
# 2020-01-01  K.L.N Sai Prasanth, Yathindra Ajay K.A, K. Pra...
# 2020-01-02    Ankit Kaushik, Gaurav Mangla, Rhitiman Majumder
# 2020-01-02                 Asheesh Chanda, Vineeth Narasimhan
# 2020-01-02                     Shubhendra Vikram, Ankit Kumar
# 2020-01-03  Charit Bhograj, Zainul Charbiwala, Udayan Dasg...
# 2020-01-03                                   Bhavish Aggarwal
# 2020-01-03      Amit Kumar Agarwal, Akhil Gupta, Saurabh Garg
# 2020-01-03                              Ajith Mohan Karimpana
# 2020-01-04   Anugrah Shrivastava, Rohan Gupta, Vasanth Kamath
# 2020-01-05   Mikhil Raj, Shubhadit Sharma, Ishaan Preet Singh
# 2020-01-05           Adhil Shetty, Arjun Shetty, Rati Shetty,
# 2020-01-06  Amrit Acharya, Srinath Ramakkrushnan, Vishal C...
# 2020-01-07                                       Saurav Kumar
# 2020-01-07                   Anuj Srivastava, Ramakant Sharma
# 2020-01-07                               Srinath Ravichandran
# 2020-01-08                    NAVEED AHAMED, SYED SAQQA ABBAS
# 2020-01-08                                       Ji Cheol Ryu
# 2020-01-08                                     Pavan Adipuram
# 2020-01-09                               Vijay Shekhar Sharma
# 2020-01-09  Amrit Acharya, Srinath Ramakkrushnan, Vishal C...
# 2020-01-09                                    Rajiv Mukherjee
# 2020-01-10                   Byju Raveendran, Divya Gokulnath
# 2020-01-11                   Sridhar Joshi, Prashant Kulkarni
# 2020-01-11                                      Aneesh Mathur
# 2020-01-11  Dr Gopichand Katragadda, Ganesh Suryanarayanan...
# 2020-01-11       Dhruv Agrawal, Himanshu Gupta, Soham Chokshi
# 2020-01-12                                 Shrishti, Prithika
# 2020-01-14               Ankit Garg, Chaitanya Ramalingegowda
# 2020-01-14                          Harsimarbir (Harsh) Singh
# 2020-01-14                                     Lalit Menghani
# 2020-01-14            Lalit Mangal, Vinay Jaasti, Manoj Singh
# 2020-01-14                                 Mihir Mohan Mishra
# 2020-01-14                          Parth Chadha, Rahul Singh
# 2020-01-16                          Varun Chopra, Raheel Shah
# 2020-01-16                                 Arun Kumar Sureban
# 2020-01-16                          Amit Naik, Kewal Vargante
# 2020-01-16  Arun George, Nikhil NP, Rashid Bin Abdulla, Vi...
# 2020-01-17                             Amit Raj, Anshul Gupta
# 2020-01-17                       Ashish Munjal, Piyush Nangru
# 2020-01-17                                      Jatin Solanki
# 2020-01-17                                     Nicky Goulimis
# 2020-01-17    Ravi Ravulaparthi, Lakshman Gupta, Vamsee Mohan
# 2020-01-17                         Altaf Saiyed, Saloni Anand
# 2020-01-18                    Aaditya Sharda, Souvik Sengupta
# 2020-01-18                           Arindam Ghosh, U R Bhatt
# 2020-01-19                       Govind Agrawal, Arti Agrawal
# 2020-01-19             Sai Srinivas Kiran G, Shubham Malhotra
# 2020-01-19             Adit Chhabra, Tapan Dixit,Tanay Dixit.
# 2020-01-19                                       Rajan Navani
# 2020-01-19                                    Byju Raveendran
#
#                                                      Investor  Amount($)  \
# Date
# 2020-01-01                          Dr. Bhaskar Rao Bollineni    3000000
# 2020-01-02                                           Swastika    4000000
# 2020-01-02                                  Chiratae Ventures    6000000
# 2020-01-02                                     Anand Mahindra    1000000
# 2020-01-03  UTEC-The University of Tokyo Edge Capital, Afl...   10500000
# 2020-01-03                                    Matrix Partners   27000000
# 2020-01-03                                   General Atlantic   30000000
# 2020-01-03                                 Chowdry Associates    2200000
# 2020-01-04              Sequoia Capital India, Blume Ventures   13400000
# 2020-01-05            Lightspeed, Elevation, Deepika Padukone    3200000
# 2020-01-05                                        WSV Capital    5967000
# 2020-01-06                                          Greenoaks   21000000
# 2020-01-07                            Inventus III India Fund    2530000
# 2020-01-07                 Mercer Investments, Nicholas Cator    9000000
# 2020-01-07                                        pi Ventures    3148000
# 2020-01-08                                             Capify    3000000
# 2020-01-08                    Kakao Ventures, Shinhan Capital    1400000
# 2020-01-08                             Unicorn India Ventures     650000
# 2020-01-09                               One97 Communications    5600000
# 2020-01-09                                    InnoVen capital    2200000
# 2020-01-09                                  Venture Catalysts    3000000
# 2020-01-10              Owl Ventures, Tiger Global Management  200000000
# 2020-01-11                                  Venture Catalysts    3000000
# 2020-01-11                                           Justdial    3000000
# 2020-01-11                                           Pratithi    3000000
# 2020-01-11                         DTDC, Udaan Angel Partners    6000000
# 2020-01-12                                        Jazal Group    3000000
# 2020-01-14                                   Sequoia Capital.   20000000
# 2020-01-14        Sequoia Capital India, Hummingbird Ventures   11000000
# 2020-01-14                               Varanium NexGen Fund    3000000
# 2020-01-14                                        Accel India    3000000
# 2020-01-14     Clairvest Group, Ontario Centres of Excellence    1020000
# 2020-01-14                       Jindal Steels, Jeet Banerjee    3000000
# 2020-01-16                                      Sequoia India    5000000
# 2020-01-16                                       Next Capital   10000000
# 2020-01-16                                       Good Capital    3000000
# 2020-01-16                             Unicorn India Ventures     300000
# 2020-01-17                IIFL Seed Ventures Fund, Menlo park    4000000
# 2020-01-17                             Prime Venture Partners    3000000
# 2020-01-17                     Rohit Chanana, Sukanta Ganguly    3000000
# 2020-01-17  Kleiner Perkins, Canapi Ventures, Index Ventur...   50000000
# 2020-01-17                    Alto Partners, Mission Holdings    1080000
# 2020-01-17                    Kae Capital, Whiteboard Capital    3000000
# 2020-01-18  Trifecta Capital Advisors, Nexus Venture Partners   20000000
# 2020-01-18                                   Pinetree Capital    3000000
# 2020-01-19                             Orios Venture Partners    3000000
# 2020-01-19               Pegasus Tech Ventures, Base Partners    5000000
# 2020-01-19                              Sequoia Capital India    2500000
# 2020-01-19            Adar C. Poonawalla, Kris Gopalakrishnan   40000000
# 2020-01-19                                    Angel investors      12700
#
#                    Stage  Year               Sector
# Date
# 2020-01-01      Series A  2020           Technology
# 2020-01-02      Series A  2020            Logistics
# 2020-01-02      Series A  2020           Technology
# 2020-01-02      Series A  2020           Technology
# 2020-01-03      Series B  2020           Healthcare
# 2020-01-03      Series A  2020              FinTech
# 2020-01-03      Series A  2020          Real Estate
# 2020-01-03      Series C  2020           E-Commerce
# 2020-01-04      Series B  2020              FinTech
# 2020-01-05          Seed  2020            Education
# 2020-01-05     Series D1  2020              FinTech
# 2020-01-06      Series C  2020            Marketing
# 2020-01-07      Series A  2020           Automotive
# 2020-01-07      Series D  2020          Real Estate
# 2020-01-07  Pre-series A  2020           Technology
# 2020-01-08          Seed  2020          Hospitality
# 2020-01-08          Seed  2020  Media/Entertainment
# 2020-01-08  Pre-series A  2020              FinTech
# 2020-01-09      Series A  2020              FinTech
# 2020-01-09      Series A  2020            Marketing
# 2020-01-09      Series A  2020           Technology
# 2020-01-10      Series A  2020            Education
# 2020-01-11    Seed Round  2020          Consumables
# 2020-01-11      Series A  2020           Automotive
# 2020-01-11      Series A  2020           Technology
# 2020-01-11      Series A  2020           Technology
# 2020-01-12  Pre-series A  2020      Wellness/Beauty
# 2020-01-14      Series B  2020    Consumer Services
# 2020-01-14      Series A  2020           Automotive
# 2020-01-14      Series A  2020              FinTech
# 2020-01-14      Series A  2020  Media/Entertainment
# 2020-01-14      Series A  2020           Automotive
# 2020-01-14  Pre-series A  2020               Gaming
# 2020-01-16      Series A  2020              FinTech
# 2020-01-16      Series A  2020           Technology
# 2020-01-16  Pre-series A  2020              Finance
# 2020-01-16      Series A  2020           Technology
# 2020-01-17      Series A  2020          Consumables
# 2020-01-17      Series A  2020            Education
# 2020-01-17      Series A  2020            Education
# 2020-01-17      Series B  2020              FinTech
# 2020-01-17          Seed  2020              FinTech
# 2020-01-17          Seed  2020           Healthcare
# 2020-01-18      Series B  2020          Real Estate
# 2020-01-18  Pre-series A  2020              FinTech
# 2020-01-19      Series A  2020           Technology
# 2020-01-19      Series A  2020               Gaming
# 2020-01-19  Pre-series A  2020           Technology
# 2020-01-19      Series A  2020           Technology
# 2020-01-19    Seed Round  2020              FinTech

# %% [markdown]
# ## Ploting visuals to check the dataframe shape

# %%
top10_hq = ind_2020.groupby('HeadQuarter')['Amount($)'].sum().sort_values(ascending=False)[:10]

plt.barh(top10_hq.index, top10_hq.values)
plt.title('Top 10 Headquarters by Funding Amount in 2020')
plt.xlabel('Funding Amount (in billions USD)')
plt.ylabel('Headquarters')
plt.show()

# %%
top10_investors = ind_2020.groupby('Investor')['Amount($)'].sum().nlargest(10)

plt.barh(top10_investors.index[::-1], top10_investors.values[::-1])
plt.xlabel('Investment Amount (in USD)')
plt.ylabel('Investor Name')
plt.title('Top 10 Investors in Indian Startups (2020)')
plt.tight_layout()
plt.show()

# %%
if ind_2020.empty:
    print("No data found for the year 2018")
else:
    # Calculate the total funding by sector
    total_funding_by_sector = ind_2018.groupby('Sector')['Amount($)'].sum().reset_index()

    top_10_sectors = total_funding_by_sector.sort_values(by='Amount($)', ascending=False).head(10)

    ax = sns.barplot(data=top_10_sectors, x='Sector', y='Amount($)')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    plt.show()

# %% [markdown]
# ## 2021

# %% [markdown]
# ## checking the data shape / filling missing values/ creating a date series

# %%
ind_2021.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor     Amount($)         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
ind_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %%
ind_2021.describe()
# Out:
#            Founded
# count  1208.000000
# mean   2016.655629
# std       4.517364
# min    1963.000000
# 25%    2015.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2021.000000

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand      0
# Founded            1
# HeadQuarter        1
# Sector             0
# What it does       0
# Founders           4
# Investor          62
# Amount($)          3
# Stage            428
# dtype: int64

# %%
#replace empty values with Nan
import pandas as pd
import numpy as np

ind_2021 = pd.DataFrame({
    'Sector': ['Tech', 'Finance', '—', 'Retail'],
    'Amount($)': [10000, 5000, np.nan, 8000],
    'Year': [2019, 2019, 2019, 2019]
})

ind_2021['Sector'].replace('—', np.nan, inplace=True)
ind_2021['Year'] = 2021

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand      0
# Founded            1
# HeadQuarter        1
# Sector             0
# What it does       0
# Founders           4
# Investor          62
# Amount($)          3
# Stage            428
# Year               0
# dtype: int64

# %%
# create a DatetimeIndex with dates for the entire year
date_range = pd.date_range(start='2021-01-01', end='2021-12-31', freq='D')

# create a new column 'Date' with random dates within the year 2018
ind_2021['Date'] = np.random.choice(date_range, size=len(ind_2021))

ind_2021 = ind_2021.sort_values('Date')

ind_2021['Date'] = pd.to_datetime(ind_2021['Date'], format='%Y-%m-%d')

# %% [markdown]
# ## mask to identify rows where the 'Stage' column contains a dollar sign and assigns the value in that row to the 'Amount column,drop specific rows by their index number and assign 'NaN' values

# %%
ind_2021.head(50)
# Out:
#               Company/Brand  Founded HeadQuarter                    Sector  \
# 720                Zotalabs   2019.0        Pune              Tech Startup
# 552             Indi Energy   2019.0     Roorkee  Renewables & Environment
# 349           Newton School   2019.0   Bangalore                    EdTech
# 210   MedPrime Technologies   2014.0       Thane                Healthcare
# 537              Oliveboard   2012.0   Bangalore                    EdTech
# 1139                 Gobbly   2019.0    Gurugram                    Retail
# 734       Five Star Finance   1984.0     Chennai                   FinTech
# 755     Nazara Technologies   2000.0      Mumbai                    Gaming
# 8                  Vitra.ai   2020.0   Bangalore              Tech Startup
# 1116               PayCardo   2021.0        Pune        Financial Services
# 357                 Progcap   2017.0   New Delhi                   FinTech
# 403                Furlenco   2012.0   Bangalore                Home Decor
# 130              CommerceUp   2018.0    Gurugram    Information Technology
# 1058         Avanti Finance   2017.0   Bangalore        Financial Services
# 1102               CashBook   2020.0    Gurugram                   FinTech
# 238           ASQI Advisors   2019.0      Mumbai        Financial Services
# 762             Livve Homes   2017.0   Bangalore              Rental space
# 773                     YAP   2014.0     Chennai                   FinTech
# 1009               Totality   2017.0    Gurugram             Entertainment
# 171               Unacademy   2015.0   Bangalore                    EdTech
# 833                 Polygon   2017.0      Mumbai                    Crypto
# 1160  Atomberg Technologies   2012.0      Mumbai      Consumer Electronics
# 636                Dropshop   2019.0   Bangalore                 Logistics
# 146             BatteryPool   2018.0        Pune                Automotive
# 780               Stylework   2017.0    Gurugram                Co-working
# 594               Avishkaar   2014.0   New Delhi                    EdTech
# 475                  Gumlet   2019.0   Bangalore                        IT
# 311               SecureNow   2011.0    Gurugram                 Insurance
# 671             Pathfndr.io   2015.0   Bangalore              SaaS startup
# 1057             Wiggles.in   2018.0        Pune                Veterinary
# 438             Legalwiz.in   2015.0   Ahmedabad                 Legaltech
# 221              LenDenClub   2015.0      Mumbai        Financial Services
# 666          India Quotient   2012.0      Mumbai        Venture capitalist
# 1007                   CRED   2018.0   Bangalore                   Finance
# 843              Disruptium   2021.0   Ahmadabad                Consulting
# 857                 6Degree   2014.0      Mumbai                    Retail
# 377               Elucidata   2015.0   New Delhi             BioTechnology
# 385                  Ruptok   2020.0   New Delhi                   FinTech
# 670            CoffeeMug.ai   2020.0   New Delhi                Networking
# 72                   Spinny   2015.0    Gurugram                    Retail
# 561         Digit Insurance   2016.0   Bangalore                Insuretech
# 985             M2P Fintech   2015.0     Chennai        Financial Services
# 1022            BookingJini   2017.0    Gurugram               Hospitality
# 1165               Anveshan   2019.0   Bangalore           Food Production
# 205                ChefKart   2020.0    Gurugram            Consumer Goods
# 450            Vanity Wagon   2018.0     Haryana                 Cosmetics
# 575            Neverinstall   2019.0   Bangalore    Information Technology
# 822                   Tekie   2017.0    Gurugram                    EdTech
# 568       Arcatron Mobility   2015.0        Pune                Healthcare
# 410                   Lohum   2017.0       Noida                EV startup
#
#                                            What it does  \
# 720   Zotalabs gives the power of Emerging Technolog...
# 552   Indi Energy is an energy storage startup invol...
# 349   Newton School is a platform to learn and devel...
# 210   MedPrime Technologies is a medical device comp...
# 537   Oliveboard is the top exam preparation platfor...
# 1139  A 24x7 automated retail store filled with dail...
# 734   Five-Star is a Registered Non Banking Finance ...
# 755   Nazara Technologies develops mobile content su...
# 8     Vitra.ai is an AI-based video translation plat...
# 1116  A true Contactless & Cashless and secure payme...
# 357   Progcap is a financial service company that pr...
# 403   Furlenco is a subscription-based furniture ren...
# 130   Grow and manage ecommerce business from single...
# 1058  A digital platform to make financial services ...
# 1102  CashBook is a digital record-keeping app using...
# 238   Bringing Blockchain technology intro mainstrea...
# 762   India's homegrown online portal, championing t...
# 773   YAP is the API Platform for Banking and Paymen...
# 1009  Totality with the goal of combining scalabilit...
# 171   Unacademy aims to build the world's largest on...
# 833       Polygon is a blockchain scalability platform.
# 1160             A maker of energy-efficient smart fans
# 636   Building technology to make distribution effic...
# 146   Building the Operating System for managing Ele...
# 780   Stylework is an unconventional co-working spac...
# 594   India's leading Ed-Tech startup spearheading t...
# 475   Gumlet has built a new-age media delivery infr...
# 311   SecureNow is an award winning tech-enabled ins...
# 671   Intelligent Travel Tech Stack making sense of ...
# 1057  Wiggles India is a preventative healthcare bra...
# 438   LegalWiz.in is committed to provide high quali...
# 221   P2P lending platform delivering high returns o...
# 666   India Quotient is a new type of early stage in...
# 1007  CRED is a credit card payment platform that re...
# 843                 A consultancy platform for startups
# 857   6Degree is a fashion retail startup that provi...
# 377   Elucidata Corporation uses data analytics to t...
# 385   Ruptok operates as a fintech platform for gold...
# 670   A video first global platform of senior profes...
# 72    Spinny is a used car buying platform enabling ...
# 561   Digit becomes the first Unicorn of 2021, value...
# 985   M2P fintech was born out of the need to build ...
# 1022  BookingJini strive to empower Hotels from all ...
# 1165  Revolutionizing the food industry through tech...
# 205   ChefKart is an end to end kitchen aide that pl...
# 450   Vanity Wagon is India’s #1 Natural Organic Bea...
# 575   A cloud platform to bring any GUI application ...
# 822   Tekie is a live coding platform for kids that ...
# 568   Mission is to advance global standards of assi...
# 410   Lohum manufactures lithium-ion battery packs a...
#
#                                                Founders  \
# 720                         Nausherwan Shah, Wasim Khan
# 552                                      Dr. ASIT SAHOO
# 349               Nishant Chandra, Siddharth Maheshwari
# 210   Samrat, Greeshma Unnikrishnan, Binil Jacob, Ma...
# 537                      Abhishek Patil, V Satish Kumar
# 1139                          Ankur Agarwal, Amit Ahuja
# 734                                     V K Ranganathan
# 755                                   Nitish Mittersain
# 8                                        Akash Nidhi PS
# 1116                   Vivek Kumar Choubey, Vivek Kumar
# 357               Pallavi Shrivastava, Himanshu Chandra
# 403                                     Ajith Karimpana
# 130                                       Piyush Pathak
# 1058                      Nandan Nilekani, Vijay Kelkar
# 1102                             Vivek, Ashutosh Pathak
# 238                                       Swapnil Pawar
# 762                                       Maya Lakshman
# 773                            Madhusudanan R, Prabhu R
# 1009                                    Anshul Rustaggi
# 171            Gaurav Munjal, Hemesh Singh, Roman Saini
# 833        Jaynti Kanani, Sandeep Nailwal, Anurag Arjun
# 1160                         Manoj Meena, Sibabrata Das
# 636             Udit Dhawan, Rohit Fernandes, Ravi Teja
# 146                                      Ashwin Shankar
# 780                                   Sparsh Khandelwal
# 594                           Rajeev Gaba, Tarun Bhalla
# 475                       Divyesh Patel, Aditya Patadia
# 311                        Kapil Mehta, Abhishek Bondia
# 671                                         Varun Gupta
# 1057                                       Anushka Iyer
# 438                         Shrijay Sheth, Gaurav Barot
# 221                          Bhavin Patel, Dipesh Karki
# 666                         Anand Lunia, Madhukar Sinha
# 1007                                         Kunal Shah
# 843              Yash Shah, Kapil Mathrani, Ishit Desai
# 857                         Amit Bhardwaj, Nikhil Hegde
# 377        Abhishek Jha, Richard Kibbey, Swetabh Pathak
# 385       Ankur Gupta, Akshita Gupta, Yashwardhan Aeren
# 670                       Abhishek Sharma, Dipti Tandon
# 72            Mohit Gupta, Niraj Singh, Ramanshu Mahaur
# 561                                        Kamesh Goyal
# 985                                      Madhusudanan R
# 1022  Deepak Dash, Gourab Kumar Nandy, Manoj Pandia,...
# 1165   Aayushi Khandelwal, Akhil Kansal, Kuldeep Parewa
# 205              Vaibhav Gupta, Arpit Gupta, Aman Gupta
# 450                                      Prateek Ruhail
# 575                        Lakshmana Pasala, Ram Pasala
# 822                           Anand Verma, Naman Mukund
# 568                                     Ganesh Sonawane
# 410                                         Rajat Verma
#
#                                                Investor     Amount($)  \
# 720                                       Alfa Ventures    $1,250,000
# 552                               Mumbai Angels Network  $undisclosed
# 349                          RTP Global, Harshil Mathur    $5,000,000
# 210                 Mumbai Angels Network, Social Alpha  $Undisclosed
# 537                                            IAN Fund      $3000000
# 1139                        Anicut Angel Fund, Sauce.VC       $900000
# 734                      TPG Capital Asia, Epiq Capital  $234,000,000
# 755   Hornbill Capital Advisers, Plutus Wealth Manag...   $30,000,000
# 8                                     Inflexor Ventures   Undisclosed
# 1116                                           MaGEHold  $Undisclosed
# 357                               Somak Ghosh, M V Nair    $1,000,000
# 403                                   BlackSoil Capital    $2,000,000
# 130                                         NB Ventures  $Undisclosed
# 1058  Oikocredit, Nomura, The Bill & Melinda Gates F...     $15000000
# 1102                      JAM, Better Tomorrow Ventures      $2300000
# 238                               Founders Room Capital      $1000000
# 762                                     Angel investors    $5,000,000
# 773                      Jitendra Gupta, Better Capital   $10,000,000
# 1009                         Leo Capital, Mayfield Fund      $1000000
# 171                                     Bhavin Turakhia  $Undisclosed
# 833                            Mark Cuban, MiH Ventures   Undisclosed
# 1160                                     Ka Enterprises  $Undisclosed
# 636                           Inflection Point Ventures      $1000000
# 146                                                 IAN  $Undisclosed
# 780                           Inflection Point Ventures      $500,000
# 594                                              Auxano       $600000
# 475                                     Sequoia’s Surge      $1600000
# 311                               Apis Insurtech Fund I      $6000000
# 671                                      Arali Ventures  $Undisclosed
# 1057                                   Anthill Ventures      $5500000
# 438                                         ContCentric      $500,000
# 221   Tuscan Ventures, Ohm Stock Brokers, Artha Vent...     $10000000
# 666                                                 NaN     $64000000
# 1007                          Tiger Global, Falcon Edge    $250000000
# 843                                       Pravesh Mehta      $200,000
# 857            Keiretsu Forum, SucSEED Venture Partners    $1,000,000
# 377                          Hyperplane Venture Capital    $5,000,000
# 385                                                Wurk   $10,000,000
# 670             Paradigm Shift Capital, AngelList India       $620000
# 72                    Arena Holdings, Think Investments   $65,000,000
# 561   Faering Capital, Sequoia Capital India, IIFL A...    $200000000
# 985                                        Tiger Global     $35000000
# 1022                              Mumbai Angels Network      $1200000
# 1165               DSG Consumer Partners, Titan Capital       $500000
# 205        Lead Angels, Titan Capital, Pravega Ventures       $300000
# 450                Dhianu Das, Agility Venture Partners      $200,000
# 575                                     Speciale Invest       $370000
# 822                              GSV, Multiply Ventures    $1,500,000
# 568                                                Klub  $undisclosed
# 410       Baring Private Equity Partners India, Talbros    $7,000,000
#
#              Stage  Year       Date
# 720           Seed  2021 2021-01-01
# 552           Seed  2021 2021-01-01
# 349       Series A  2021 2021-01-01
# 210           Seed  2021 2021-01-02
# 537            NaN  2021 2021-01-03
# 1139  Pre-series A  2021 2021-01-03
# 734            NaN  2021 2021-01-03
# 755            NaN  2021 2021-01-03
# 8              NaN  2021 2021-01-03
# 1116      Pre-seed  2021 2021-01-03
# 357           Debt  2021 2021-01-03
# 403            NaN  2021 2021-01-03
# 130           Seed  2021 2021-01-04
# 1058     Series A2  2021 2021-01-04
# 1102          Seed  2021 2021-01-04
# 238   Pre-series A  2021 2021-01-04
# 762            NaN  2021 2021-01-04
# 773       Series B  2021 2021-01-05
# 1009           NaN  2021 2021-01-05
# 171            NaN  2021 2021-01-05
# 833            NaN  2021 2021-01-06
# 1160           NaN  2021 2021-01-08
# 636   Pre-series A  2021 2021-01-08
# 146           Seed  2021 2021-01-08
# 780   Pre-series A  2021 2021-01-09
# 594   Pre-series A  2021 2021-01-09
# 475            NaN  2021 2021-01-09
# 311       Series B  2021 2021-01-10
# 671   Pre-series A  2021 2021-01-10
# 1057  Pre-series A  2021 2021-01-10
# 438            NaN  2021 2021-01-11
# 221       Series A  2021 2021-01-11
# 666            NaN  2021 2021-01-11
# 1007      Series E  2021 2021-01-11
# 843            NaN  2021 2021-01-11
# 857            NaN  2021 2021-01-11
# 377   Pre-series A  2021 2021-01-12
# 385            NaN  2021 2021-01-12
# 670       Pre-seed  2021 2021-01-13
# 72        Series C  2021 2021-01-14
# 561            NaN  2021 2021-01-14
# 985       Series C  2021 2021-01-14
# 1022  Pre-series A  2021 2021-01-14
# 1165          Seed  2021 2021-01-14
# 205       Pre-seed  2021 2021-01-14
# 450           Seed  2021 2021-01-14
# 575           Seed  2021 2021-01-14
# 822           Seed  2021 2021-01-15
# 568            NaN  2021 2021-01-15
# 410            NaN  2021 2021-01-16

# %%
mask = (~ind_2021['Stage'].isna()) & ind_2021['Stage'].str.contains('\$')
ind_2021.loc[mask, 'Amount($)'] = ind_2021.loc[mask, 'Stage']
ind_2021.loc[mask, 'Stage'] = ''

mask = (~ind_2021['Investor'].isna()) & ind_2021['Investor'].str.contains('\$')
ind_2021.loc[mask, 'Amount($)'] = ind_2021.loc[mask, 'Investor']
ind_2021.loc[mask, 'Investor'] = ''


ind_2021 = ind_2021.drop(111)

ind_2021 = ind_2021.drop(256)

ind_2021.loc[902, 'Investor'] = np.nan

ind_2021.loc[59, 'Investor'] = np.nan

ind_2021.loc[1100, 'Investor'] = np.nan

ind_2021.loc[1148, 'Investor'] = np.nan

# %%
ind_2021.head(60)
# Out:
#               Company/Brand  Founded             HeadQuarter  \
# 720                Zotalabs   2019.0                    Pune
# 552             Indi Energy   2019.0                 Roorkee
# 349           Newton School   2019.0               Bangalore
# 210   MedPrime Technologies   2014.0                   Thane
# 537              Oliveboard   2012.0               Bangalore
# 1139                 Gobbly   2019.0                Gurugram
# 734       Five Star Finance   1984.0                 Chennai
# 755     Nazara Technologies   2000.0                  Mumbai
# 8                  Vitra.ai   2020.0               Bangalore
# 1116               PayCardo   2021.0                    Pune
# 357                 Progcap   2017.0               New Delhi
# 403                Furlenco   2012.0               Bangalore
# 130              CommerceUp   2018.0                Gurugram
# 1058         Avanti Finance   2017.0               Bangalore
# 1102               CashBook   2020.0                Gurugram
# 238           ASQI Advisors   2019.0                  Mumbai
# 762             Livve Homes   2017.0               Bangalore
# 773                     YAP   2014.0                 Chennai
# 1009               Totality   2017.0                Gurugram
# 171               Unacademy   2015.0               Bangalore
# 833                 Polygon   2017.0                  Mumbai
# 1160  Atomberg Technologies   2012.0                  Mumbai
# 636                Dropshop   2019.0               Bangalore
# 146             BatteryPool   2018.0                    Pune
# 780               Stylework   2017.0                Gurugram
# 594               Avishkaar   2014.0               New Delhi
# 475                  Gumlet   2019.0               Bangalore
# 311               SecureNow   2011.0                Gurugram
# 671             Pathfndr.io   2015.0               Bangalore
# 1057             Wiggles.in   2018.0                    Pune
# 438             Legalwiz.in   2015.0               Ahmedabad
# 221              LenDenClub   2015.0                  Mumbai
# 666          India Quotient   2012.0                  Mumbai
# 1007                   CRED   2018.0               Bangalore
# 843              Disruptium   2021.0               Ahmadabad
# 857                 6Degree   2014.0                  Mumbai
# 377               Elucidata   2015.0               New Delhi
# 385                  Ruptok   2020.0               New Delhi
# 670            CoffeeMug.ai   2020.0               New Delhi
# 72                   Spinny   2015.0                Gurugram
# 561         Digit Insurance   2016.0               Bangalore
# 985             M2P Fintech   2015.0                 Chennai
# 1022            BookingJini   2017.0                Gurugram
# 1165               Anveshan   2019.0               Bangalore
# 205                ChefKart   2020.0                Gurugram
# 450            Vanity Wagon   2018.0                 Haryana
# 575            Neverinstall   2019.0               Bangalore
# 822                   Tekie   2017.0                Gurugram
# 568       Arcatron Mobility   2015.0                    Pune
# 410                   Lohum   2017.0                   Noida
# 806                Lenskart   2010.0      Faridabad, Haryana
# 242      Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 1117               Aerchain   2019.0               Bangalore
# 359     Nazara Technologies   2000.0                  Mumbai
# 551                   BHyve   2020.0                  Mumbai
# 28               TrulyMadly   2013.0               New Delhi
# 635          SimpliContract   2020.0               Bangalore
# 262                Nestasia   2018.0                 Kolkata
# 169             Whiz League   2020.0               New Delhi
# 905            GuardianLink   2017.0                 Chennai
#
#                                                  Sector  \
# 720                                        Tech Startup
# 552                            Renewables & Environment
# 349                                              EdTech
# 210                                          Healthcare
# 537                                              EdTech
# 1139                                             Retail
# 734                                             FinTech
# 755                                              Gaming
# 8                                          Tech Startup
# 1116                                 Financial Services
# 357                                             FinTech
# 403                                          Home Decor
# 130                              Information Technology
# 1058                                 Financial Services
# 1102                                            FinTech
# 238                                  Financial Services
# 762                                        Rental space
# 773                                             FinTech
# 1009                                      Entertainment
# 171                                              EdTech
# 833                                              Crypto
# 1160                               Consumer Electronics
# 636                                           Logistics
# 146                                          Automotive
# 780                                          Co-working
# 594                                              EdTech
# 475                                                  IT
# 311                                           Insurance
# 671                                        SaaS startup
# 1057                                         Veterinary
# 438                                           Legaltech
# 221                                  Financial Services
# 666                                  Venture capitalist
# 1007                                            Finance
# 843                                          Consulting
# 857                                              Retail
# 377                                       BioTechnology
# 385                                             FinTech
# 670                                          Networking
# 72                                               Retail
# 561                                          Insuretech
# 985                                  Financial Services
# 1022                                        Hospitality
# 1165                                    Food Production
# 205                                      Consumer Goods
# 450                                           Cosmetics
# 575                              Information Technology
# 822                                              EdTech
# 568                                          Healthcare
# 410                                          EV startup
# 806                                             Fashion
# 242   Primary Business is Development and Manufactur...
# 1117                                  Computer Software
# 359                                              Gaming
# 551                                     Human Resources
# 28                                               Dating
# 635                                            Software
# 262                                              Retail
# 169                                              EdTech
# 905                   Information Technology & Services
#
#                                            What it does  \
# 720   Zotalabs gives the power of Emerging Technolog...
# 552   Indi Energy is an energy storage startup invol...
# 349   Newton School is a platform to learn and devel...
# 210   MedPrime Technologies is a medical device comp...
# 537   Oliveboard is the top exam preparation platfor...
# 1139  A 24x7 automated retail store filled with dail...
# 734   Five-Star is a Registered Non Banking Finance ...
# 755   Nazara Technologies develops mobile content su...
# 8     Vitra.ai is an AI-based video translation plat...
# 1116  A true Contactless & Cashless and secure payme...
# 357   Progcap is a financial service company that pr...
# 403   Furlenco is a subscription-based furniture ren...
# 130   Grow and manage ecommerce business from single...
# 1058  A digital platform to make financial services ...
# 1102  CashBook is a digital record-keeping app using...
# 238   Bringing Blockchain technology intro mainstrea...
# 762   India's homegrown online portal, championing t...
# 773   YAP is the API Platform for Banking and Paymen...
# 1009  Totality with the goal of combining scalabilit...
# 171   Unacademy aims to build the world's largest on...
# 833       Polygon is a blockchain scalability platform.
# 1160             A maker of energy-efficient smart fans
# 636   Building technology to make distribution effic...
# 146   Building the Operating System for managing Ele...
# 780   Stylework is an unconventional co-working spac...
# 594   India's leading Ed-Tech startup spearheading t...
# 475   Gumlet has built a new-age media delivery infr...
# 311   SecureNow is an award winning tech-enabled ins...
# 671   Intelligent Travel Tech Stack making sense of ...
# 1057  Wiggles India is a preventative healthcare bra...
# 438   LegalWiz.in is committed to provide high quali...
# 221   P2P lending platform delivering high returns o...
# 666   India Quotient is a new type of early stage in...
# 1007  CRED is a credit card payment platform that re...
# 843                 A consultancy platform for startups
# 857   6Degree is a fashion retail startup that provi...
# 377   Elucidata Corporation uses data analytics to t...
# 385   Ruptok operates as a fintech platform for gold...
# 670   A video first global platform of senior profes...
# 72    Spinny is a used car buying platform enabling ...
# 561   Digit becomes the first Unicorn of 2021, value...
# 985   M2P fintech was born out of the need to build ...
# 1022  BookingJini strive to empower Hotels from all ...
# 1165  Revolutionizing the food industry through tech...
# 205   ChefKart is an end to end kitchen aide that pl...
# 450   Vanity Wagon is India’s #1 Natural Organic Bea...
# 575   A cloud platform to bring any GUI application ...
# 822   Tekie is a live coding platform for kids that ...
# 568   Mission is to advance global standards of assi...
# 410   Lohum manufactures lithium-ion battery packs a...
# 806   Lenskart is an India-based online shopping por...
# 242                                        Varun Khanna
# 1117  Advance Source-to-Pay cycle to a new level wit...
# 359   Nazara Technologies develops mobile content su...
# 551   A Future of Work Platform for diffusing Employ...
# 28    Trulymadly is a dating platform that uses a ma...
# 635   SimpliContract is an Enterprise SaaS offering,...
# 262   Artisanal, Handmade, bio conscious crafts from...
# 169   Revolutionizing learning experience that goes ...
# 905   Building tech infrastructure to help NFT comme...
#
#                                                Founders  \
# 720                         Nausherwan Shah, Wasim Khan
# 552                                      Dr. ASIT SAHOO
# 349               Nishant Chandra, Siddharth Maheshwari
# 210   Samrat, Greeshma Unnikrishnan, Binil Jacob, Ma...
# 537                      Abhishek Patil, V Satish Kumar
# 1139                          Ankur Agarwal, Amit Ahuja
# 734                                     V K Ranganathan
# 755                                   Nitish Mittersain
# 8                                        Akash Nidhi PS
# 1116                   Vivek Kumar Choubey, Vivek Kumar
# 357               Pallavi Shrivastava, Himanshu Chandra
# 403                                     Ajith Karimpana
# 130                                       Piyush Pathak
# 1058                      Nandan Nilekani, Vijay Kelkar
# 1102                             Vivek, Ashutosh Pathak
# 238                                       Swapnil Pawar
# 762                                       Maya Lakshman
# 773                            Madhusudanan R, Prabhu R
# 1009                                    Anshul Rustaggi
# 171            Gaurav Munjal, Hemesh Singh, Roman Saini
# 833        Jaynti Kanani, Sandeep Nailwal, Anurag Arjun
# 1160                         Manoj Meena, Sibabrata Das
# 636             Udit Dhawan, Rohit Fernandes, Ravi Teja
# 146                                      Ashwin Shankar
# 780                                   Sparsh Khandelwal
# 594                           Rajeev Gaba, Tarun Bhalla
# 475                       Divyesh Patel, Aditya Patadia
# 311                        Kapil Mehta, Abhishek Bondia
# 671                                         Varun Gupta
# 1057                                       Anushka Iyer
# 438                         Shrijay Sheth, Gaurav Barot
# 221                          Bhavin Patel, Dipesh Karki
# 666                         Anand Lunia, Madhukar Sinha
# 1007                                         Kunal Shah
# 843              Yash Shah, Kapil Mathrani, Ishit Desai
# 857                         Amit Bhardwaj, Nikhil Hegde
# 377        Abhishek Jha, Richard Kibbey, Swetabh Pathak
# 385       Ankur Gupta, Akshita Gupta, Yashwardhan Aeren
# 670                       Abhishek Sharma, Dipti Tandon
# 72            Mohit Gupta, Niraj Singh, Ramanshu Mahaur
# 561                                        Kamesh Goyal
# 985                                      Madhusudanan R
# 1022  Deepak Dash, Gourab Kumar Nandy, Manoj Pandia,...
# 1165   Aayushi Khandelwal, Akhil Kansal, Kuldeep Parewa
# 205              Vaibhav Gupta, Arpit Gupta, Aman Gupta
# 450                                      Prateek Ruhail
# 575                        Lakshmana Pasala, Ram Pasala
# 822                           Anand Verma, Naman Mukund
# 568                                     Ganesh Sonawane
# 410                                         Rajat Verma
# 806                       Amit Chaudhary, Peyush Bansal
# 242                  Morgan Stanley Private Equity Asia
# 1117                Harsha Kadimisetty, Himavanth Jasti
# 359                                   Nitish Mittersain
# 551                                   Backed by 100x.VC
# 28           Hitesh Dhingra, Rahul Kumar, Sachin Bhatia
# 635           Guru Venkatesan, Jinaraj PG, Makesh Kumar
# 262               Aditi Murarka Agrawal, Anurag Agrawal
# 169                   Natasha Jain, Sonia Agarwal Bajaj
# 905              Ramkumar Subramaniam, Kamesh Elangovan
#
#                                                Investor     Amount($)  \
# 720                                       Alfa Ventures    $1,250,000
# 552                               Mumbai Angels Network  $undisclosed
# 349                          RTP Global, Harshil Mathur    $5,000,000
# 210                 Mumbai Angels Network, Social Alpha  $Undisclosed
# 537                                            IAN Fund      $3000000
# 1139                        Anicut Angel Fund, Sauce.VC       $900000
# 734                      TPG Capital Asia, Epiq Capital  $234,000,000
# 755   Hornbill Capital Advisers, Plutus Wealth Manag...   $30,000,000
# 8                                     Inflexor Ventures   Undisclosed
# 1116                                           MaGEHold  $Undisclosed
# 357                               Somak Ghosh, M V Nair    $1,000,000
# 403                                   BlackSoil Capital    $2,000,000
# 130                                         NB Ventures  $Undisclosed
# 1058  Oikocredit, Nomura, The Bill & Melinda Gates F...     $15000000
# 1102                      JAM, Better Tomorrow Ventures      $2300000
# 238                               Founders Room Capital      $1000000
# 762                                     Angel investors    $5,000,000
# 773                      Jitendra Gupta, Better Capital   $10,000,000
# 1009                         Leo Capital, Mayfield Fund      $1000000
# 171                                     Bhavin Turakhia  $Undisclosed
# 833                            Mark Cuban, MiH Ventures   Undisclosed
# 1160                                     Ka Enterprises  $Undisclosed
# 636                           Inflection Point Ventures      $1000000
# 146                                                 IAN  $Undisclosed
# 780                           Inflection Point Ventures      $500,000
# 594                                              Auxano       $600000
# 475                                     Sequoia’s Surge      $1600000
# 311                               Apis Insurtech Fund I      $6000000
# 671                                      Arali Ventures  $Undisclosed
# 1057                                   Anthill Ventures      $5500000
# 438                                         ContCentric      $500,000
# 221   Tuscan Ventures, Ohm Stock Brokers, Artha Vent...     $10000000
# 666                                                 NaN     $64000000
# 1007                          Tiger Global, Falcon Edge    $250000000
# 843                                       Pravesh Mehta      $200,000
# 857            Keiretsu Forum, SucSEED Venture Partners    $1,000,000
# 377                          Hyperplane Venture Capital    $5,000,000
# 385                                                Wurk   $10,000,000
# 670             Paradigm Shift Capital, AngelList India       $620000
# 72                    Arena Holdings, Think Investments   $65,000,000
# 561   Faering Capital, Sequoia Capital India, IIFL A...    $200000000
# 985                                        Tiger Global     $35000000
# 1022                              Mumbai Angels Network      $1200000
# 1165               DSG Consumer Partners, Titan Capital       $500000
# 205        Lead Angels, Titan Capital, Pravega Ventures       $300000
# 450                Dhianu Das, Agility Venture Partners      $200,000
# 575                                     Speciale Invest       $370000
# 822                              GSV, Multiply Ventures    $1,500,000
# 568                                                Klub  $undisclosed
# 410       Baring Private Equity Partners India, Talbros    $7,000,000
# 806           Kohlberg Kravis Roberts, Temasek Holdings   $95,000,000
# 242                                                         $22000000
# 1117                     Season Two Ventures, IndiaMart      $3000000
# 359      Plutus Wealth Management, Turtle Entertainment   $10,000,000
# 551                     Omkar Pandharkame, Ketaki Ogale       $300000
# 28                         Gaurav Munjal, Snehil Khanor    $2,000,000
# 635                                     Kalaari Capital      $1800000
# 262                            Varun Alagh, Sahil Barua      $4000000
# 169                            ITI Growth Opportunities       $300000
# 905                                     Kalaari Capital     $12000000
#
#              Stage  Year       Date
# 720           Seed  2021 2021-01-01
# 552           Seed  2021 2021-01-01
# 349       Series A  2021 2021-01-01
# 210           Seed  2021 2021-01-02
# 537            NaN  2021 2021-01-03
# 1139  Pre-series A  2021 2021-01-03
# 734            NaN  2021 2021-01-03
# 755            NaN  2021 2021-01-03
# 8              NaN  2021 2021-01-03
# 1116      Pre-seed  2021 2021-01-03
# 357           Debt  2021 2021-01-03
# 403            NaN  2021 2021-01-03
# 130           Seed  2021 2021-01-04
# 1058     Series A2  2021 2021-01-04
# 1102          Seed  2021 2021-01-04
# 238   Pre-series A  2021 2021-01-04
# 762            NaN  2021 2021-01-04
# 773       Series B  2021 2021-01-05
# 1009           NaN  2021 2021-01-05
# 171            NaN  2021 2021-01-05
# 833            NaN  2021 2021-01-06
# 1160           NaN  2021 2021-01-08
# 636   Pre-series A  2021 2021-01-08
# 146           Seed  2021 2021-01-08
# 780   Pre-series A  2021 2021-01-09
# 594   Pre-series A  2021 2021-01-09
# 475            NaN  2021 2021-01-09
# 311       Series B  2021 2021-01-10
# 671   Pre-series A  2021 2021-01-10
# 1057  Pre-series A  2021 2021-01-10
# 438            NaN  2021 2021-01-11
# 221       Series A  2021 2021-01-11
# 666            NaN  2021 2021-01-11
# 1007      Series E  2021 2021-01-11
# 843            NaN  2021 2021-01-11
# 857            NaN  2021 2021-01-11
# 377   Pre-series A  2021 2021-01-12
# 385            NaN  2021 2021-01-12
# 670       Pre-seed  2021 2021-01-13
# 72        Series C  2021 2021-01-14
# 561            NaN  2021 2021-01-14
# 985       Series C  2021 2021-01-14
# 1022  Pre-series A  2021 2021-01-14
# 1165          Seed  2021 2021-01-14
# 205       Pre-seed  2021 2021-01-14
# 450           Seed  2021 2021-01-14
# 575           Seed  2021 2021-01-14
# 822           Seed  2021 2021-01-15
# 568            NaN  2021 2021-01-15
# 410            NaN  2021 2021-01-16
# 806            NaN  2021 2021-01-16
# 242            NaN  2021 2021-01-16
# 1117  Pre-series A  2021 2021-01-16
# 359            NaN  2021 2021-01-16
# 551                 2021 2021-01-17
# 28    Pre-series A  2021 2021-01-17
# 635           Seed  2021 2021-01-18
# 262       Series A  2021 2021-01-18
# 169            NaN  2021 2021-01-18
# 905       Series A  2021 2021-01-19

# %%
ind_2021['HeadQuarter'].ffill(inplace=True)

ind_2021['Stage'] = ind_2021['Stage'].fillna(ind_2021['Stage'].mode()[0])

# %%
mode_value = ind_2021['Investor'].mode()[0]
print(mode_value)
# Out:
# Inflection Point Ventures

# %%
ind_2021['Investor'] = ind_2021['Investor'].fillna(ind_2021['Investor'].mode()[0])

# %%
mode_value = ind_2021['Founders'].mode()[0]
print(mode_value)
# Out:
# Ashneer Grover, Shashvat Nakrani

# %%
ind_2021['Founders'] = ind_2021['Founders'].fillna(ind_2021['Founders'].mode()[0])

# %%
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].str.replace('New Delhi', 'Delhi')
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].str.replace('Gurgaon', 'Gurugram')

# %%
unique_values = ind_2021['HeadQuarter'].unique()
print(unique_values)
# Out:
# ['Pune' 'Roorkee' 'Bangalore' 'Thane' 'Gurugram' 'Chennai' 'Mumbai'
#  'Delhi' 'Ahmedabad' 'Ahmadabad' 'Haryana' 'Noida' 'Faridabad, Haryana'
#  'Pharmaceuticals\t#REF!' 'Kolkata' 'Hyderabad' 'Faridabad' 'Gandhinagar'
#  'Computer Games' 'Jaipur' 'Small Towns, Andhra Pradesh' 'Nagpur'
#  'Coimbatore' 'Kanpur' 'Information Technology & Services' 'Panaji'
#  'Gujarat' 'The Nilgiris' 'Panchkula' 'Ghaziabad' 'Samsitpur'
#  'Thiruvananthapuram' 'Gurugram\t#REF!' 'Chandigarh' 'Ranchi' 'New York'
#  'Surat' 'Orissia' 'Silvassa' 'Online Media\t#REF!' 'Goa' 'Bhilwara'
#  'Kottayam' 'Satara' 'Trivandrum' 'Lucknow' 'Kochi' 'Beijing' 'Mangalore'
#  'Guwahati' 'Ambernath' 'Mountain View, CA' 'Andheri' 'Jharkhand'
#  'Jodhpur' 'Cochin' 'Powai' 'Indore' 'Food & Beverages' 'Telangana'
#  'Mohali' 'Santra' 'London' 'Telugana' 'Bhubaneswar' 'Vadodara'
#  'West Bengal' 'Patna' 'Rajsamand']

# %%
ind_2021.drop('What it does', axis=1,inplace=True)

# %% [markdown]
# ## Replacing the missing values in the founded column by using Statiscal means

# %%
plt.hist(ind_2021['Founded'], bins=20)
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.ylabel('Frequency')
plt.show()

# %%
ind_2021['Founded'] = pd.to_numeric(ind_2021['Founded'], errors='coerce')

# %%
ind_2021['Founded'] = ind_2021['Founded'].fillna(ind_2021['Founded'].median())

# %%
ind_2021.head(50)
# Out:
#               Company/Brand  Founded HeadQuarter                    Sector  \
# 720                Zotalabs   2019.0        Pune              Tech Startup
# 552             Indi Energy   2019.0     Roorkee  Renewables & Environment
# 349           Newton School   2019.0   Bangalore                    EdTech
# 210   MedPrime Technologies   2014.0       Thane                Healthcare
# 537              Oliveboard   2012.0   Bangalore                    EdTech
# 1139                 Gobbly   2019.0    Gurugram                    Retail
# 734       Five Star Finance   1984.0     Chennai                   FinTech
# 755     Nazara Technologies   2000.0      Mumbai                    Gaming
# 8                  Vitra.ai   2020.0   Bangalore              Tech Startup
# 1116               PayCardo   2021.0        Pune        Financial Services
# 357                 Progcap   2017.0       Delhi                   FinTech
# 403                Furlenco   2012.0   Bangalore                Home Decor
# 130              CommerceUp   2018.0    Gurugram    Information Technology
# 1058         Avanti Finance   2017.0   Bangalore        Financial Services
# 1102               CashBook   2020.0    Gurugram                   FinTech
# 238           ASQI Advisors   2019.0      Mumbai        Financial Services
# 762             Livve Homes   2017.0   Bangalore              Rental space
# 773                     YAP   2014.0     Chennai                   FinTech
# 1009               Totality   2017.0    Gurugram             Entertainment
# 171               Unacademy   2015.0   Bangalore                    EdTech
# 833                 Polygon   2017.0      Mumbai                    Crypto
# 1160  Atomberg Technologies   2012.0      Mumbai      Consumer Electronics
# 636                Dropshop   2019.0   Bangalore                 Logistics
# 146             BatteryPool   2018.0        Pune                Automotive
# 780               Stylework   2017.0    Gurugram                Co-working
# 594               Avishkaar   2014.0       Delhi                    EdTech
# 475                  Gumlet   2019.0   Bangalore                        IT
# 311               SecureNow   2011.0    Gurugram                 Insurance
# 671             Pathfndr.io   2015.0   Bangalore              SaaS startup
# 1057             Wiggles.in   2018.0        Pune                Veterinary
# 438             Legalwiz.in   2015.0   Ahmedabad                 Legaltech
# 221              LenDenClub   2015.0      Mumbai        Financial Services
# 666          India Quotient   2012.0      Mumbai        Venture capitalist
# 1007                   CRED   2018.0   Bangalore                   Finance
# 843              Disruptium   2021.0   Ahmadabad                Consulting
# 857                 6Degree   2014.0      Mumbai                    Retail
# 377               Elucidata   2015.0       Delhi             BioTechnology
# 385                  Ruptok   2020.0       Delhi                   FinTech
# 670            CoffeeMug.ai   2020.0       Delhi                Networking
# 72                   Spinny   2015.0    Gurugram                    Retail
# 561         Digit Insurance   2016.0   Bangalore                Insuretech
# 985             M2P Fintech   2015.0     Chennai        Financial Services
# 1022            BookingJini   2017.0    Gurugram               Hospitality
# 1165               Anveshan   2019.0   Bangalore           Food Production
# 205                ChefKart   2020.0    Gurugram            Consumer Goods
# 450            Vanity Wagon   2018.0     Haryana                 Cosmetics
# 575            Neverinstall   2019.0   Bangalore    Information Technology
# 822                   Tekie   2017.0    Gurugram                    EdTech
# 568       Arcatron Mobility   2015.0        Pune                Healthcare
# 410                   Lohum   2017.0       Noida                EV startup
#
#                                                Founders  \
# 720                         Nausherwan Shah, Wasim Khan
# 552                                      Dr. ASIT SAHOO
# 349               Nishant Chandra, Siddharth Maheshwari
# 210   Samrat, Greeshma Unnikrishnan, Binil Jacob, Ma...
# 537                      Abhishek Patil, V Satish Kumar
# 1139                          Ankur Agarwal, Amit Ahuja
# 734                                     V K Ranganathan
# 755                                   Nitish Mittersain
# 8                                        Akash Nidhi PS
# 1116                   Vivek Kumar Choubey, Vivek Kumar
# 357               Pallavi Shrivastava, Himanshu Chandra
# 403                                     Ajith Karimpana
# 130                                       Piyush Pathak
# 1058                      Nandan Nilekani, Vijay Kelkar
# 1102                             Vivek, Ashutosh Pathak
# 238                                       Swapnil Pawar
# 762                                       Maya Lakshman
# 773                            Madhusudanan R, Prabhu R
# 1009                                    Anshul Rustaggi
# 171            Gaurav Munjal, Hemesh Singh, Roman Saini
# 833        Jaynti Kanani, Sandeep Nailwal, Anurag Arjun
# 1160                         Manoj Meena, Sibabrata Das
# 636             Udit Dhawan, Rohit Fernandes, Ravi Teja
# 146                                      Ashwin Shankar
# 780                                   Sparsh Khandelwal
# 594                           Rajeev Gaba, Tarun Bhalla
# 475                       Divyesh Patel, Aditya Patadia
# 311                        Kapil Mehta, Abhishek Bondia
# 671                                         Varun Gupta
# 1057                                       Anushka Iyer
# 438                         Shrijay Sheth, Gaurav Barot
# 221                          Bhavin Patel, Dipesh Karki
# 666                         Anand Lunia, Madhukar Sinha
# 1007                                         Kunal Shah
# 843              Yash Shah, Kapil Mathrani, Ishit Desai
# 857                         Amit Bhardwaj, Nikhil Hegde
# 377        Abhishek Jha, Richard Kibbey, Swetabh Pathak
# 385       Ankur Gupta, Akshita Gupta, Yashwardhan Aeren
# 670                       Abhishek Sharma, Dipti Tandon
# 72            Mohit Gupta, Niraj Singh, Ramanshu Mahaur
# 561                                        Kamesh Goyal
# 985                                      Madhusudanan R
# 1022  Deepak Dash, Gourab Kumar Nandy, Manoj Pandia,...
# 1165   Aayushi Khandelwal, Akhil Kansal, Kuldeep Parewa
# 205              Vaibhav Gupta, Arpit Gupta, Aman Gupta
# 450                                      Prateek Ruhail
# 575                        Lakshmana Pasala, Ram Pasala
# 822                           Anand Verma, Naman Mukund
# 568                                     Ganesh Sonawane
# 410                                         Rajat Verma
#
#                                                Investor     Amount($)  \
# 720                                       Alfa Ventures    $1,250,000
# 552                               Mumbai Angels Network  $undisclosed
# 349                          RTP Global, Harshil Mathur    $5,000,000
# 210                 Mumbai Angels Network, Social Alpha  $Undisclosed
# 537                                            IAN Fund      $3000000
# 1139                        Anicut Angel Fund, Sauce.VC       $900000
# 734                      TPG Capital Asia, Epiq Capital  $234,000,000
# 755   Hornbill Capital Advisers, Plutus Wealth Manag...   $30,000,000
# 8                                     Inflexor Ventures   Undisclosed
# 1116                                           MaGEHold  $Undisclosed
# 357                               Somak Ghosh, M V Nair    $1,000,000
# 403                                   BlackSoil Capital    $2,000,000
# 130                                         NB Ventures  $Undisclosed
# 1058  Oikocredit, Nomura, The Bill & Melinda Gates F...     $15000000
# 1102                      JAM, Better Tomorrow Ventures      $2300000
# 238                               Founders Room Capital      $1000000
# 762                                     Angel investors    $5,000,000
# 773                      Jitendra Gupta, Better Capital   $10,000,000
# 1009                         Leo Capital, Mayfield Fund      $1000000
# 171                                     Bhavin Turakhia  $Undisclosed
# 833                            Mark Cuban, MiH Ventures   Undisclosed
# 1160                                     Ka Enterprises  $Undisclosed
# 636                           Inflection Point Ventures      $1000000
# 146                                                 IAN  $Undisclosed
# 780                           Inflection Point Ventures      $500,000
# 594                                              Auxano       $600000
# 475                                     Sequoia’s Surge      $1600000
# 311                               Apis Insurtech Fund I      $6000000
# 671                                      Arali Ventures  $Undisclosed
# 1057                                   Anthill Ventures      $5500000
# 438                                         ContCentric      $500,000
# 221   Tuscan Ventures, Ohm Stock Brokers, Artha Vent...     $10000000
# 666                           Inflection Point Ventures     $64000000
# 1007                          Tiger Global, Falcon Edge    $250000000
# 843                                       Pravesh Mehta      $200,000
# 857            Keiretsu Forum, SucSEED Venture Partners    $1,000,000
# 377                          Hyperplane Venture Capital    $5,000,000
# 385                                                Wurk   $10,000,000
# 670             Paradigm Shift Capital, AngelList India       $620000
# 72                    Arena Holdings, Think Investments   $65,000,000
# 561   Faering Capital, Sequoia Capital India, IIFL A...    $200000000
# 985                                        Tiger Global     $35000000
# 1022                              Mumbai Angels Network      $1200000
# 1165               DSG Consumer Partners, Titan Capital       $500000
# 205        Lead Angels, Titan Capital, Pravega Ventures       $300000
# 450                Dhianu Das, Agility Venture Partners      $200,000
# 575                                     Speciale Invest       $370000
# 822                              GSV, Multiply Ventures    $1,500,000
# 568                                                Klub  $undisclosed
# 410       Baring Private Equity Partners India, Talbros    $7,000,000
#
#              Stage  Year       Date
# 720           Seed  2021 2021-01-01
# 552           Seed  2021 2021-01-01
# 349       Series A  2021 2021-01-01
# 210           Seed  2021 2021-01-02
# 537           Seed  2021 2021-01-03
# 1139  Pre-series A  2021 2021-01-03
# 734           Seed  2021 2021-01-03
# 755           Seed  2021 2021-01-03
# 8             Seed  2021 2021-01-03
# 1116      Pre-seed  2021 2021-01-03
# 357           Debt  2021 2021-01-03
# 403           Seed  2021 2021-01-03
# 130           Seed  2021 2021-01-04
# 1058     Series A2  2021 2021-01-04
# 1102          Seed  2021 2021-01-04
# 238   Pre-series A  2021 2021-01-04
# 762           Seed  2021 2021-01-04
# 773       Series B  2021 2021-01-05
# 1009          Seed  2021 2021-01-05
# 171           Seed  2021 2021-01-05
# 833           Seed  2021 2021-01-06
# 1160          Seed  2021 2021-01-08
# 636   Pre-series A  2021 2021-01-08
# 146           Seed  2021 2021-01-08
# 780   Pre-series A  2021 2021-01-09
# 594   Pre-series A  2021 2021-01-09
# 475           Seed  2021 2021-01-09
# 311       Series B  2021 2021-01-10
# 671   Pre-series A  2021 2021-01-10
# 1057  Pre-series A  2021 2021-01-10
# 438           Seed  2021 2021-01-11
# 221       Series A  2021 2021-01-11
# 666           Seed  2021 2021-01-11
# 1007      Series E  2021 2021-01-11
# 843           Seed  2021 2021-01-11
# 857           Seed  2021 2021-01-11
# 377   Pre-series A  2021 2021-01-12
# 385           Seed  2021 2021-01-12
# 670       Pre-seed  2021 2021-01-13
# 72        Series C  2021 2021-01-14
# 561           Seed  2021 2021-01-14
# 985       Series C  2021 2021-01-14
# 1022  Pre-series A  2021 2021-01-14
# 1165          Seed  2021 2021-01-14
# 205       Pre-seed  2021 2021-01-14
# 450           Seed  2021 2021-01-14
# 575           Seed  2021 2021-01-14
# 822           Seed  2021 2021-01-15
# 568           Seed  2021 2021-01-15
# 410           Seed  2021 2021-01-16

# %% [markdown]
# ## Filtering & replacing missing values in the the amount col, containing the sector col into categories by putting them in substrings

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        1
# Stage            0
# Year             0
# Date             0
# dtype: int64

# %%
#replace empty values with NaN
import pandas as pd
import numpy as np

ind_2021 = pd.DataFrame({
    'Sector': ['Tech', 'Finance', '—', 'Retail'],
    'Amount($)': [10000, 5000, np.nan, 8000],
    'Year': [2019, 2019, 2019, 2019]
})

ind_2021['Sector'].replace('—', np.nan, inplace=True)
ind_2021['Year'] = 2021

# %%
ind_2021['Amount($)'] = ind_2021['Amount($)'].replace('undisclosed', np.nan)

# %%
import pandas as pd
import numpy as np

ind_2021 = pd.DataFrame({
    'Sector': ['Tech', 'Finance', '—', 'Retail'],
    'Amount($)': ['$10,000', '5000.50', 'non-numeric', '8000'],
    'Year': [2019, 2019, 2019, 2019]
})

# replace empty values with NaN
ind_2021['Sector'].replace('—', np.nan, inplace=True)

# # if it is not already a string, convert it to string
if ind_2021['Amount($)'].dtype != 'object':
    ind_2021['Amount($)'] = ind_2021['Amount($)'].astype(str)

# # remove non-numeric characters from the 'Amount' column
ind_2021['Amount($)'] = ind_2021['Amount($)'].str.replace('[^\d\.]', '')

ind_2021['Amount($)'] = pd.to_numeric(ind_2021['Amount($)'], errors='coerce')

# %%
# Replace NaN values with 0
ind_2021['Amount($)'] = ind_2021['Amount($)'].fillna(0)

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# Date             0
# dtype: int64

# %%
plt.hist(ind_2021['Amount($)'], bins=20)
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(ind_2021['Amount($)'])
plt.title('Distribution of Amount')
plt.xlabel('Amount($)')
plt.show()

# %%
ind_2021['Amount($)'].replace(0, np.nan, inplace=True)

# %%
# Fill missing values with median value
ind_2021['Amount($)'].fillna(ind_2021['Amount($)'].mean(), inplace=True)

ind_2021['Amount($)'] = ind_2021['Amount($)'].astype(int)

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# Date             0
# dtype: int64

# %%
ind_2021.head()
# Out:
#              Company/Brand  Founded HeadQuarter                    Sector  \
# 720               Zotalabs   2019.0        Pune              Tech Startup
# 552            Indi Energy   2019.0     Roorkee  Renewables & Environment
# 349          Newton School   2019.0   Bangalore                    EdTech
# 210  MedPrime Technologies   2014.0       Thane                Healthcare
# 537             Oliveboard   2012.0   Bangalore                    EdTech
#
#                                               Founders  \
# 720                        Nausherwan Shah, Wasim Khan
# 552                                     Dr. ASIT SAHOO
# 349              Nishant Chandra, Siddharth Maheshwari
# 210  Samrat, Greeshma Unnikrishnan, Binil Jacob, Ma...
# 537                     Abhishek Patil, V Satish Kumar
#
#                                 Investor  Amount($)     Stage  Year       Date
# 720                        Alfa Ventures    1250000      Seed  2021 2021-01-01
# 552                Mumbai Angels Network  169032154      Seed  2021 2021-01-01
# 349           RTP Global, Harshil Mathur    5000000  Series A  2021 2021-01-01
# 210  Mumbai Angels Network, Social Alpha  169032154      Seed  2021 2021-01-02
# 537                             IAN Fund    3000000      Seed  2021 2021-01-03

# %%
# # Create a list of substrings to search for in the Sector column
tech = ['Mobile','Technology', 'Internet', 'Software', 'Hardware','SaaS','Blockchain','Apps','Information Services','SEM',
        'Artificial Intelligence','CleanTech','Aerospace','Robotics','Ai','PaaS','Medtech','Agritech','HR tech',
       'Tech','FoodTech','Safety tech','IoT','Legal tech','Infratech','Netwokring platform','Telecommunication','Cloud','Aero',
       'Virtual','Content','Photonics','app','Proptech','Deeptech','AR','VR','Agri tech','-Tech','AgriTech','IT','Network',
        'Data','HrTech','Foodtech','Spacetech','E-mobility','Automation','Logitech','HRTech','Drone','MLOps','Innovation',
       'BioTechnology','TaaS','network','equipment','SpaceTech','CRM','MarTech','Nanotechnology','Femtech','startup','AI']
fin = ['Lending','Finance','Insurance', 'Payments','Financial Services','Credit','Credit Cards','Mutual Funds',
       'Banking','Escrow','Venture','financial','Taxation','Capital','firm','Equity']
fint = ['NFT','Virtual Banking','FinTech','Fintech','Cryptocurrency','Crypto','Insurtech','InsurTech']
health = ['Health', 'Medical','Pharmaceutical','Health Diagnotics','Health Care','Hospital','Biotechnology','Biopharma',
         'Hygiene management','HealthTech','Healthcare','HealthCare','laboratory','Biotech','Healthtech','HeathTech',
         'Helathcare','Veterinary']
mkt = ['Brand Marketing','Marketing','Event Promotion','Market']
agric = ['Farming','Agriculture','Nutrition','Hauz Khas','Fishery']
con = ['Food','Food and Beverages','Dairy','Beverages','Beer','FMCG']
econ = ['B2B','Shopping','E-Commerce','Trading Platform','E-commerce','E-marketplace','marketplace','e-commerce','Ecommerce',
        'E-market','Commerce','Trading platform']
cons = ['Wholesale','Consumer','Shoes','Packaging','Retail','Consulting','Food Delivery']
edu = ['E-Learning','EdTech','Education','Communities','Edtech','Preschool','School']
welln = ['Lifestyle','Beauty','Wellness','Cosmetics','Yoga','Skincare','D2C','Fitness','Lifestyle','Training']
real_est=['Real Estate','Home Decor','Accomodation','Interior design','Home Design','Home interior','Co-living',
          'Construction']
log = ['Logistics','Rental','Tourism','Travel','TravelTech','Transport','Transportation','Aviation','Mobility']

auto = ['Automotive','Electric vehicle','Industrial Automation','Vehicles','Automotive tech','Automobile','Tyre','car','Car',
       'Vehicle','Mechanical']
manu = ['Manufacturing']
ener = ['Renewable Energy','Solar','Energy','Energy Storage','Battery','Oil and Gas','Renewable','EV','Electricity',
       'purification','Renewables']
medi = ['Entertainment','Media','News','Video','Digital Media','FM','Publication','OTT','Social Network','Music',
        'Digital platform','Podcast','publishing','Blogging']
Game = ['Gaming','Games','Sports']

style = ['Fashion','Jewelry','Eyeglasses','Eye Wear','Apparel','Dating','Celebrity','Eyewear','D2C Fashion','Matrimony',
         'Textiles','D2C jewellery','Foootwear','Arts']
hos =['Hospitality','Hotel','Leisure']


ind_2021['Sector_clean'] = 'Other'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(tech)), 'Sector_clean'] = 'Technology'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(fin)), 'Sector_clean'] = 'Finance'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(health)), 'Sector_clean'] = 'Healthcare'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(mkt)), 'Sector_clean'] = 'Marketing'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(agric)), 'Sector_clean'] = 'Agriculture'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(econ)), 'Sector_clean'] = 'E-Commerce'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(edu)), 'Sector_clean'] = 'Education'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(welln)), 'Sector_clean'] = 'Wellness/Beauty'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(real_est)), 'Sector_clean'] = 'Real Estate'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(log)), 'Sector_clean'] = 'Logistics'

ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(auto)), 'Sector_clean'] = 'Automotive'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(manu)), 'Sector_clean'] = 'Manufacture'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(ener)), 'Sector_clean'] = 'Energy'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(medi)), 'Sector_clean'] = 'Media/Entertainment'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(hos)), 'Sector_clean'] = 'Hospitality'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(style)), 'Sector_clean'] = 'Lifestyle'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(cons)), 'Sector_clean'] = 'Consumer Services'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(game)), 'Sector_clean'] = 'Gaming'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(fint)), 'Sector_clean'] = 'FinTech'
ind_2021.loc[ind_2021['Sector'].str.contains('|'.join(con)), 'Sector_clean'] = 'Consumables'

# %%
# replace the value in row  of Column1 with NaN & fill/replace with mode

ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Food & Beverages', np.nan)
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Pharmaceuticals\t#REF!', np.nan)
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Online Media#REF!', np.nan)
ind_2021.loc[98, 'HeadQuarter'] = np.nan
ind_2021.loc[1100, 'HeadQuarter'] = np.nan

ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Gurugram\t#REF!', 'Gurugram')
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Information Technology & Services', 'Manchester')
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Mountain View, CA', 'California')
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Faridabad, Haryana', 'Haryana')
ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].replace('Small Towns, Andhra Pradesh', 'Andhra Pradesh')


ind_2021['HeadQuarter'] = ind_2021['HeadQuarter'].fillna(ind_2021['HeadQuarter'].mode()[0])

# %%
# filling the gaps with appropriate naming convention

ind_2021['Sector'] = ind_2021['Sector'].replace('Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.', 'Healthcare')
ind_2021['Sector'] = ind_2021['Sector'].replace('Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.', 'Healthcare')   
ind_2021['Sector'] = ind_2021['Sector'].replace('MoEVing is Indias only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.', 'Energy')

# %%
unique_values = ind_2021['HeadQuarter'].unique()
print(unique_values)
# Out:
# ['Pune' 'Roorkee' 'Bangalore' 'Thane' 'Gurugram' 'Chennai' 'Mumbai'
#  'Delhi' 'Ahmedabad' 'Ahmadabad' 'Haryana' 'Noida' 'Kolkata' 'Hyderabad'
#  'Faridabad' 'Gandhinagar' 'Jaipur' 'Andhra Pradesh' 'Nagpur' 'Coimbatore'
#  'Kanpur' 'Manchester' 'Panaji' 'Gujarat' 'The Nilgiris' 'Panchkula'
#  'Ghaziabad' 'Samsitpur' 'Thiruvananthapuram' 'Chandigarh' 'Ranchi'
#  'New York' 'Surat' 'Orissia' 'Silvassa' 'Goa' 'Bhilwara' 'Kottayam'
#  'Satara' 'Trivandrum' 'Lucknow' 'Kochi' 'Beijing' 'Mangalore' 'Guwahati'
#  'Ambernath' 'California' 'Andheri' 'Jharkhand' 'Jodhpur' 'Cochin' 'Powai'
#  'Indore' 'Telangana' 'Mohali' 'Santra' 'London' 'Telugana' 'Bhubaneswar'
#  'Vadodara' 'West Bengal' 'Patna' 'Rajsamand']

# %%
ind_2021.head()
# Out:
#              Company/Brand  Founded HeadQuarter                    Sector  \
# 720               Zotalabs   2019.0        Pune              Tech Startup
# 552            Indi Energy   2019.0     Roorkee  Renewables & Environment
# 349          Newton School   2019.0   Bangalore                    EdTech
# 210  MedPrime Technologies   2014.0       Thane                Healthcare
# 537             Oliveboard   2012.0   Bangalore                    EdTech
#
#                                               Founders  \
# 720                        Nausherwan Shah, Wasim Khan
# 552                                     Dr. ASIT SAHOO
# 349              Nishant Chandra, Siddharth Maheshwari
# 210  Samrat, Greeshma Unnikrishnan, Binil Jacob, Ma...
# 537                     Abhishek Patil, V Satish Kumar
#
#                                 Investor  Amount($)     Stage  Year  \
# 720                        Alfa Ventures    1250000      Seed  2021
# 552                Mumbai Angels Network  169032154      Seed  2021
# 349           RTP Global, Harshil Mathur    5000000  Series A  2021
# 210  Mumbai Angels Network, Social Alpha  169032154      Seed  2021
# 537                             IAN Fund    3000000      Seed  2021
#
#           Date Sector_clean
# 720 2021-01-01   Technology
# 552 2021-01-01       Energy
# 349 2021-01-01    Education
# 210 2021-01-02   Automotive
# 537 2021-01-03    Education

# %%
ind_2021.isna().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# Date             0
# Sector_clean     0
# dtype: int64

# %%
ind_2021.drop(ind_2021.columns[-8], axis=1,inplace=True)

# %%
ind_2021= ind_2021.rename(columns={'Sector_clean': 'Sector'})

# %%
ind_2021['Founded'] = ind_2021['Founded'].astype(int)

# %%
ind_2021.head()
# Out:
#              Company/Brand  Founded HeadQuarter  \
# 720               Zotalabs     2019        Pune
# 552            Indi Energy     2019     Roorkee
# 349          Newton School     2019   Bangalore
# 210  MedPrime Technologies     2014       Thane
# 537             Oliveboard     2012   Bangalore
#
#                                               Founders  \
# 720                        Nausherwan Shah, Wasim Khan
# 552                                     Dr. ASIT SAHOO
# 349              Nishant Chandra, Siddharth Maheshwari
# 210  Samrat, Greeshma Unnikrishnan, Binil Jacob, Ma...
# 537                     Abhishek Patil, V Satish Kumar
#
#                                 Investor  Amount($)     Stage  Year  \
# 720                        Alfa Ventures    1250000      Seed  2021
# 552                Mumbai Angels Network  169032154      Seed  2021
# 349           RTP Global, Harshil Mathur    5000000  Series A  2021
# 210  Mumbai Angels Network, Social Alpha  169032154      Seed  2021
# 537                             IAN Fund    3000000      Seed  2021
#
#           Date      Sector
# 720 2021-01-01  Technology
# 552 2021-01-01      Energy
# 349 2021-01-01   Education
# 210 2021-01-02  Automotive
# 537 2021-01-03   Education

# %%
ind_2021.set_index('Date',inplace=True)

# %% [markdown]
# ## Ploting visuals to check the shape of the dataframe

# %%
if ind_2021.empty:
    print("No data found for the year 2021")
else:
    # Calculate the total funding by sector
    total_funding_by_sector = ind_2021.groupby('Sector')['Amount($)'].sum().reset_index()

    top_10_sectors = total_funding_by_sector.sort_values(by='Amount($)', ascending=False).head(10)

    ax = sns.barplot(data=top_10_sectors, x='Sector', y='Amount($)')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    plt.show()

# %%
# sort the dataframe by amount in descending order and select the top 10 investors
top_investors = ind_2021.sort_values(by='Amount($)', ascending=False).head(10)

# create a horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(top_investors['Investor'], top_investors['Amount($)'], color='purple')

ax.set_xlabel('Amount($)', fontsize=12)

ax.set_ylabel('Investor', fontsize=12)

ax.set_title('Top 10 Investors by Amount', fontsize=14)

plt.show()

# %% [markdown]
# ## filling missing values in 2018 with merged data, checking the correlation,converting amount col to float

# %%
# Compute the correlation matrix
combined_ind = pd.concat([ind_2019, ind_2020, ind_2021], axis=0)

correlation_matrix = combined_ind.corr()

print(correlation_matrix)
# Out:
#             Founded  Amount($)      Year
# Founded    1.000000   0.038671  0.151788
# Amount($)  0.038671   1.000000  0.110487
# Year       0.151788   0.110487  1.000000

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand      0
# Stage              0
# Amount($)          0
# Year               0
# Founded          526
# HeadQuarter        0
# Sector             0
# dtype: int64

# %%
plt.hist(combined_ind['Founded'], bins=50)
plt.title('Distribution of Year')
plt.xlabel('Founded')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculate the median of the column
median_value = combined_ind['Founded'].median()

# %%
ind_2018['Founded'].fillna(median_value, inplace=True)

# %%
ind_2018.isna().sum()
# Out:
# Company/Brand    0
# Stage            0
# Amount($)        0
# Year             0
# Founded          0
# HeadQuarter      0
# Sector           0
# dtype: int64

# %%
ind_2018['Founded'] = ind_2018['Founded'].astype(int)

# %%
ind_2018.head()
# Out:
#                 Company/Brand            Stage  Amount($)  Year  Founded  \
# Date
# 2018-01-01            Vebbler             Seed    5800000  2018     2016
# 2018-01-01          StockEdge             Seed    1100000  2018     2016
# 2018-01-02     Max Healthcare  Corporate Round    5800000  2018     2016
# 2018-01-03  Creator’s Gurukul            Angel    5800000  2018     2016
# 2018-01-03   Innov8 Coworking             Seed    4000000  2018     2016
#
#            HeadQuarter               Sector
# Date
# 2018-01-01   Bangalore  Media/Entertainment
# 2018-01-01     Kolkata            Marketing
# 2018-01-02       Delhi           Automotive
# 2018-01-03    Gurugram                Other
# 2018-01-03       Delhi          Real Estate

# %%
ind_2018["Amount($)"] = ind_2018["Amount($)"].astype(float)

ind_2019["Amount($)"] = ind_2019["Amount($)"].astype(float)

ind_2020["Amount($)"] = ind_2020["Amount($)"].astype(float)

ind_2021["Amount($)"] = ind_2021["Amount($)"].astype(float)

# %% [markdown]
# ## Some more data cleaning in the HeadQuarter column

# %%
# concatenate all the dataframes into one
ind_st2 = pd.concat([ind_2018, ind_2019, ind_2020, ind_2021], ignore_index=True)

# %%
# replace "Bengaluru" with "Bangalore" in the "headquarter" column
ind_st2['HeadQuarter'] = ind_st2['HeadQuarter'].str.replace('Bombay', 'Mumbai')

# %%
ind_st2['Stage'] = ind_st2['Stage'].fillna(ind_st2['Stage'].mode()[0])

# %%
# Drop rows with the value "Sochcast" in the "Company/Brand" column in-place
ind_2021.drop(ind_2021[ind_2021['Company/Brand'] == 'Sochcast'].index, inplace=True)

# %%
unique_values = ind_2021['HeadQuarter'].unique()
print(unique_values)
# Out:
# ['Pune' 'Roorkee' 'Bangalore' 'Thane' 'Gurugram' 'Chennai' 'Mumbai'
#  'Delhi' 'Ahmedabad' 'Ahmadabad' 'Haryana' 'Noida' 'Kolkata' 'Hyderabad'
#  'Faridabad' 'Gandhinagar' 'Jaipur' 'Andhra Pradesh' 'Nagpur' 'Coimbatore'
#  'Kanpur' 'Manchester' 'Panaji' 'Gujarat' 'The Nilgiris' 'Panchkula'
#  'Ghaziabad' 'Samsitpur' 'Thiruvananthapuram' 'Chandigarh' 'Ranchi'
#  'New York' 'Surat' 'Orissia' 'Silvassa' 'Goa' 'Bhilwara' 'Kottayam'
#  'Satara' 'Trivandrum' 'Lucknow' 'Kochi' 'Beijing' 'Mangalore' 'Guwahati'
#  'Ambernath' 'California' 'Andheri' 'Jharkhand' 'Jodhpur' 'Cochin' 'Powai'
#  'Indore' 'Telangana' 'Mohali' 'Santra' 'London' 'Telugana' 'Bhubaneswar'
#  'Vadodara' 'West Bengal' 'Patna' 'Rajsamand']

# %%
ind_st2['HeadQuarter'] = ind_st2['HeadQuarter'].str.replace('Bengaluru', 'Bangalore')

# %%
unique_values = ind_st2['HeadQuarter'].unique()
print(unique_values)
# Out:
# ['Bangalore' 'Kolkata' 'Delhi' 'Gurugram' 'Ahmedabad' 'Mumbai' 'Hyderabad'
#  'Noida' 'Jaipur' 'Kochi' 'Pune' 'Haryana' 'Chennai' 'Anand' 'India'
#  'Bhopal' 'Ghaziabad' 'Indore' 'Thane' 'Lucknow' 'Ernakulam' 'Chandigarh'
#  'Azadpur' 'Andheri' 'Mohali' 'Worli' 'Guindy' 'Uttar Pradesh' 'Alwar'
#  'Jodhpur' 'Belgaum' 'Kalpakkam' 'Coimbatore' 'Trivandrum' 'Kormangala'
#  'Powai' 'Hubli' 'Alleppey' 'Faridabad' 'Kanpur' 'Kannur' 'Margão'
#  'Cochin' 'Guntur' 'Mylapore' 'Kalkaji' 'Kota' 'Telangana' 'Rajasthan'
#  'Uttar pradesh' 'Surat' 'Seoul' 'Kerala' 'Singapore' 'London'
#  'Bangaldesh' 'California' 'Gujarat' 'Queensland' 'San Ramon'
#  'San Francisco' 'Tamil Nadu' 'Bihar' 'Texas' 'France' 'Hyderebad'
#  'New York' 'Sydney' 'Goa' 'San Franciscao' 'Dehradun' 'Rajastan'
#  'Karnataka' 'Tamilnadu' 'Shanghai' 'Riyadh' 'Milano' 'Berlin' 'Paris'
#  'Jawa Barat' 'Warangal' 'Newcastle' 'Patna' 'Ludhiana' 'Bangkok' 'Odisha'
#  'Biphar' 'Seattle' 'Jiaxing' 'Roorkee' 'Ahmadabad' 'Gandhinagar'
#  'Andhra Pradesh' 'Nagpur' 'Manchester' 'Panaji' 'The Nilgiris'
#  'Panchkula' 'Samsitpur' 'Thiruvananthapuram' 'Ranchi' 'Orissia'
#  'Silvassa' 'Bhilwara' 'Kottayam' 'Satara' 'Beijing' 'Mangalore'
#  'Guwahati' 'Ambernath' 'Jharkhand' 'Santra' 'Telugana' 'Bhubaneswar'
#  'Vadodara' 'West Bengal' 'Rajsamand']

# %%
# Group the data by headquarters location and calculate the average funding amount
grouped = ind_st2.groupby('HeadQuarter')['Amount($)'].mean()

# Sort the data by average funding amount in descending order
grouped = grouped.sort_values(ascending=False)

# Select the top 20 headquarters locations
top_20 = grouped[:20]

# Create a horizontal bar chart to visualize the relationship between headquarters location and funding amounts
plt.barh(top_20.index, top_20.values)
plt.xlabel('Average Funding Amount')
plt.ylabel('Headquarters Location')
plt.title('Top 20 Headquarters Locations by Average Funding Amount')

# Display the plot
plt.show()

# %%
# save dataframe to a CSV file
ind_2018.to_csv('clean-startup-2018.csv',index_label='Date')
ind_2019.to_csv('clean-startup-2019.csv',index_label='Date')
ind_2020.to_csv('clean-startup-2020.csv',index_label='Date')
ind_2021.to_csv('clean-startup-2021.csv',index_label='Date')
